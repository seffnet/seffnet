# %% [markdown]
# # Using the Prediction Model
#
# ## Environment

# %%
import getpass
import json
import os
import sys
import time

import pandas as pd
from tqdm import tqdm_notebook as tqdm

from seffnet.constants import (
    DEFAULT_EMBEDDINGS_PATH, DEFAULT_GRAPH_PATH,
    DEFAULT_MAPPING_PATH, DEFAULT_PREDICTIVE_MODEL_PATH,
    RESOURCES
)
from seffnet.literature import query_europe_pmc

# %%
print(sys.version)
# Out:
# 3.7.4 (default, Aug 13 2019, 11:17:01)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-36)]

# %%
print(time.asctime())
# Out:
# Tue Nov 12 13:26:44 2019

# %%
print(getpass.getuser())
# Out:
# raldisi

# %% [markdown]
# # Loading the Data

# %%
from seffnet.default_predictor import predictor

# %%
print(f"""Loaded default predictor using paths:

embeddings: {DEFAULT_EMBEDDINGS_PATH}
graph:      {DEFAULT_GRAPH_PATH}
model:      {DEFAULT_PREDICTIVE_MODEL_PATH}
mapping:    {DEFAULT_MAPPING_PATH}
""")
# Out:
# Loaded default predictor using paths:
#
# embeddings: /home/raldisi/seffnet/resources/embeddings/0411_weighted_node2vec_emb.embeddings
# graph:      /home/raldisi/seffnet/resources/basic_graphs/fullgraph_with_chemsim.edgelist
# model:      /home/raldisi/seffnet/resources/predictive_models/0411_weighted_node2vec_predictive_model.pkl
# mapping:    /home/raldisi/seffnet/resources/mapping/fullgraph_nodes_mapping.tsv

# %% [markdown]
# # Examples of different kinds of predictions with literature evidence

# %% [markdown]
# ## side effect - target association

# %%
r = predictor.find_new_relation(
    source_name='EGFR_HUMAN',
    target_name='Papulopustular rash',
)
print(json.dumps(r, indent=2))
#PMID: 18165622
# Out:
# {
#   "source": {
#     "node_id": "9587",
#     "namespace": "uniprot",
#     "identifier": "P00533",
#     "name": "EGFR_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "6791",
#     "namespace": "umls",
#     "identifier": "C2609319",
#     "name": "Papulopustular rash",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.84067
# }

# %%
r = predictor.find_new_relation(
    source_id='9451', # Histamine receptor H1
    target_id='331', # Drowsiness
)
print(json.dumps(r, indent=2))
#PMID: 26626077
# Out:
# {
#   "source": {
#     "node_id": "9451",
#     "namespace": "uniprot",
#     "identifier": "P35367",
#     "name": "HRH1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "331",
#     "namespace": "umls",
#     "identifier": "C0013144",
#     "name": "Drowsiness",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00895
# }

# %%
r = predictor.find_new_relation(
    source_id='9325', # SC6A2
    target_id='56', # Tachycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "9325",
#     "namespace": "uniprot",
#     "identifier": "P23975",
#     "name": "SC6A2_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "56",
#     "namespace": "umls",
#     "identifier": "C0039231",
#     "name": "Tachycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.13985
# }

# %%
r = predictor.find_new_relation(
    source_id='8670', # ACES_HUMAN
    target_id='309', # Bradycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "309",
#     "namespace": "umls",
#     "identifier": "C0428977",
#     "name": "Bradycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.44455
# }

# %% [markdown]
# ## drug- side effect association

# %%
r = predictor.find_new_relation(
    source_id='3534',  # diazepam
    target_id='670',  # Libido decreased
)
print(json.dumps(r, indent=2))
#PMID: 29888057
# Out:
# {
#   "source": {
#     "node_id": "3534",
#     "namespace": "pubchem.compound",
#     "identifier": "3016",
#     "name": "Diazepam",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "670",
#     "namespace": "umls",
#     "identifier": "C0011124",
#     "name": "Libido decreased",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.03777
# }

# %%
r = predictor.find_new_relation(
    source_id='1148',  # Cytarabine 
    target_id='1149',  # Anaemia megaloblastic
)
print(json.dumps(r, indent=2))
# PMID: 23157436
# Out:
# {
#   "source": {
#     "node_id": "1148",
#     "namespace": "pubchem.compound",
#     "identifier": "6175",
#     "name": "Cytidine",
#     "entity_type": "experimental drug"
#   },
#   "target": {
#     "node_id": "1149",
#     "namespace": "umls",
#     "identifier": "C0002888",
#     "name": "Anaemia megaloblastic",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.30869
# }

# %% [markdown]
# ## drug-target association

# %%
r = predictor.find_new_relation(
    source_id='14672',  # Sertindole 
    target_id='9350',   # CHRM1 receptor
)
print(json.dumps(r, indent=2))
# PMID: 29942259
# Out:
# {
#   "source": {
#     "node_id": "14672",
#     "namespace": "pubchem.compound",
#     "identifier": "60149",
#     "name": "Sertindole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN",
#     "entity_type": "target"
#   },
#   "lor": 0.02472
# }

# %% [markdown]
# # Example of predicting relations using node2vec model and embeddings

# %%
def get_predictions_df(curie, results_type=None):
    results = predictor.find_new_relations(
        node_curie=curie,
        results_type=results_type,
        k=50,
    )
    results_df = pd.DataFrame(results['predictions'])
    results_df = results_df[['node_id', 'namespace', 'identifier', 'name', 'lor', 'novel']]
    return results['query'], results_df

# %%
query, df = get_predictions_df('pubchem.compound:2159', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2173",
#     "namespace": "pubchem.compound",
#     "identifier": "2159",
#     "name": "Amisulpride",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                            name      lor  \
# 0     1062      umls   C0497327                        Dementia  0.00040
# 1     6249      umls   C0036337        Schizoaffective disorder  0.00048
# 2      797      umls   C0338831                           Mania  0.00065
# 3      821      umls   C0233632               Thinking abnormal  0.00117
# 4     1074      umls   C0575081                Gait disturbance  0.00127
# 5      540      umls   C0042075          Urinary tract disorder  0.00156
# 6      799      umls   C0151836               Paranoid reaction  0.00168
# 7      651      umls   C0005586                Bipolar disorder  0.00174
# 8      950      umls   C0007787      Transient ischaemic attack  0.00175
# 9     2248      umls   C0030567             Parkinson's disease  0.00175
# 10     181      umls   C0036974                           Shock  0.00177
# 11     568      umls   C0018939                  Blood disorder  0.00187
# 12    1396      umls   C0023066                    Laryngospasm  0.00191
# 13     816      umls   C0232461              Increased appetite  0.00198
# 14      44      umls   C0026826                      Hypertonia  0.00209
# 15     602      umls   C0013362                      Dysarthria  0.00211
# 16     535      umls   C0031212            Personality disorder  0.00216
# 17     652      umls   C0853193              Bipolar I disorder  0.00219
# 18      28      umls   C0015397                    Eye disorder  0.00222
# 19     552      umls   C0085628                          Stupor  0.00232
# 20     403      umls   C0002884             Hypochromic anaemia  0.00240
# 21     684      umls   C0014394                        Enuresis  0.00241
# 22      41      umls   C0023218     Cramps of lower extremities  0.00242
# 23    1539      umls   C0006384             Bundle branch block  0.00244
# 24    1732      umls   C0037822                 Speech disorder  0.00265
# 25     599      umls   C0085632                          Apathy  0.00267
# 26     903      umls   C0574067                 Cough increased  0.00269
# 27      77      umls   C0947912                      Myasthenia  0.00269
# 28    1016      umls   C0151766    Liver function test abnormal  0.00271
# 29    2140      umls   C0151878  Electrocardiogram QT prolonged  0.00273
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
query, df = get_predictions_df('pubchem.compound:4585', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "4915",
#     "namespace": "pubchem.compound",
#     "identifier": "4585",
#     "name": "Olanzapine",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                          name      lor  novel
# 0     1016      umls   C0151766  Liver function test abnormal  0.00014   True
# 1      735      umls   C0028734                      Nocturia  0.00018   True
# 2      287      umls   C0042401                  Vasodilation  0.00035   True
# 3     1391      umls   C0019270                        Hernia  0.00039   True
# 4      870      umls   C0424000             Suicidal ideation  0.00040   True
# 5      834      umls   C0235198          Cerebration impaired  0.00044   True
# 6      774      umls   C0043387                       Yawning  0.00050   True
# 7     4633      umls   C0751495              Partial seizures  0.00052   True
# 8     2175      umls   C1457883           Aggressive reaction  0.00070   True
# 9      767      umls   C0039503                    Tendonitis  0.00073   True
# 10    1399      umls   C0151603            Generalised oedema  0.00076   True
# 11     641      umls   C0151889                 Hyperreflexia  0.00076   True
# 12    1072      umls   C0554976                  Bradyphrenia  0.00079   True
# 13    1156      umls   C0018991                    Hemiplegia  0.00084   True
# 14     474      umls   C0427008                     Stiffness  0.00088   True
# 15     995      umls   C0034150                       Purpura  0.00089   True
# 16     371      umls   C0014549          Grand mal convulsion  0.00100   True
# 17     663      umls   C0009319                       Colitis  0.00100   True
# 18     818      umls   C0233477                     Dysphoria  0.00102   True
# 19    1390      umls   C0019209                  Hepatomegaly  0.00108   True
# 20     676      umls   C0011606        Dermatitis exfoliative  0.00109   True
# 21     437      umls   C0033575            Prostatic disorder  0.00110   True
# 22     105      umls   C0031256                     Petechiae  0.00113   True
# 23     305      umls   C0392171       Influenza-like symptoms  0.00115   True
# 24     734      umls   C0028084                     Nightmare  0.00117   True
# 25    2145      umls   C0231303                      Distress  0.00119   True
# 26    1479      umls   C0917798            Cerebral ischaemia  0.00121   True
# 27     782      umls   C0086769                  Panic attack  0.00121   True
# 28    2445      umls   C0235901      Lacrimation abnormal NOS  0.00124   True
# 29      87      umls   C0003537                       Aphasia  0.00125   True

# %%
query, df = get_predictions_df('uniprot:P08172', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "9429",
#     "namespace": "uniprot",
#     "identifier": "P08172",
#     "name": "ACM2_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                  name  \
# 0      198      umls   C0006266                          Bronchospasm
# 1      705      umls   C1322281                     Rhinitis seasonal
# 2     1823      umls   C0559031  Functional gastrointestinal disorder
# 3      398      umls   C0423153                           Lacrimation
# 4      957      umls   C0009443                           Common cold
# 5     2043      umls   C2607914                     Rhinitis allergic
# 6       81      umls   C0002792                    Anaphylactic shock
# 7      674      umls   C0011334                         Dental caries
# 8      673      umls   C0011253                              Delusion
# 9      728      umls   C0026837                       Muscle rigidity
# 10    2180      umls   C0152198                Accommodation disorder
# 11     394      umls   C0036104                            Salivation
# 12     924      umls   C0878773                    Hypertonic bladder
# 13     668      umls   C0232849                          Bladder pain
# 14     427      umls   C0026961                             Mydriasis
# 15     289      umls   C0043352                             Dry mouth
# 16    1297      umls   C0018794                           Block heart
# 17    3568      umls   C0235238                           Cycloplegia
# 18     780      umls   C0086439                           Hypokinesia
# 19     852      umls   C0242422                          Parkinsonism
# 20    1398      umls   C0030920                          Peptic ulcer
# 21    5127      umls   C0027404                            Narcolepsy
# 22     218      umls   C0040822                                Tremor
# 23    2248      umls   C0030567                   Parkinson's disease
# 24     821      umls   C0233632                     Thinking abnormal
# 25     224      umls   C0080274                     Urinary retention
# 26     395      umls   C0037036               Salivary hypersecretion
# 27    1909      umls   C1704272          Benign prostatic hyperplasia
# 28     625      umls   C0018524                         Hallucination
# 29     331      umls   C0013144                            Drowsiness
#
#         lor  novel
# 0   0.00935   True
# 1   0.01444   True
# 2   0.01459   True
# 3   0.01618   True
# 4   0.02012   True
# 5   0.02136   True
# 6   0.02383   True
# 7   0.02415   True
# 8   0.02488   True
# 9   0.02972   True
# 10  0.03056   True
# 11  0.03354   True
# 12  0.03359   True
# 13  0.03442   True
# 14  0.03611   True
# 15  0.03632   True
# 16  0.03798   True
# 17  0.03847   True
# 18  0.03938   True
# 19  0.04616   True
# 20  0.04619   True
# 21  0.04777   True
# 22  0.04795   True
# 23  0.04810   True
# 24  0.04853   True
# 25  0.04902   True
# 26  0.04966   True
# 27  0.05051   True
# 28  0.05251   True
# 29  0.05325   True

# %%
query, df = get_predictions_df('uniprot:P08588', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8733",
#     "namespace": "uniprot",
#     "identifier": "P08588",
#     "name": "ADRB1_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                     name  \
# 0     1325      umls   C0857121                             Hypertensive
# 1     7641      umls   C0017612                      Open angle glaucoma
# 2       38      umls   C0020538                             Hypertension
# 3      444      umls   C0039240             Supraventricular tachycardia
# 4     7640      umls   C0339573              Primary open angle glaucoma
# 5      198      umls   C0006266                             Bronchospasm
# 6     7709      umls   C0340288                   Stable angina pectoris
# 7     7642      umls   C0857070              Chronic open angle glaucoma
# 8     1714      umls   C0004239                           Atrial flutter
# 9      103      umls   C0027769                              Nervousness
# 10     349      umls   C0085614      Atrioventricular block first degree
# 11    7508      umls   C0043202           Wolff-Parkinson-White syndrome
# 12    8163      umls   C0242407              Hyperkinetic heart syndrome
# 13    7507      umls   C0030590  Paroxysmal supraventricular tachycardia
# 14      56      umls   C0039231                              Tachycardia
# 15    1102      umls   C0002962                          Angina pectoris
# 16     503      umls   C3665386                          Abnormal vision
# 17      47      umls   C0030252                             Palpitations
# 18     218      umls   C0040822                                   Tremor
# 19    3692      umls   C0085580                   Essential hypertension
# 20    2203      umls   C0428974              Arrhythmia supraventricular
# 21      10      umls   C0003811                               Arrhythmia
# 22    7769      umls   C0428776                            Cardiac index
# 23    4348      umls   C0232201                             Sinus rhythm
# 24     132      umls   C0234215                               Discomfort
# 25     331      umls   C0013144                               Drowsiness
# 26    5509      umls   C0011881                     Diabetic nephropathy
# 27     270      umls   C0020550                          Hyperthyroidism
# 28     353      umls   C0151517          Atrioventricular block complete
# 29    3494      umls   C0028840                      Ocular hypertension
#
#         lor  novel
# 0   0.00220   True
# 1   0.00320   True
# 2   0.00497   True
# 3   0.00731   True
# 4   0.00879   True
# 5   0.01146   True
# 6   0.01170   True
# 7   0.01324   True
# 8   0.01366   True
# 9   0.01462   True
# 10  0.01563   True
# 11  0.01637   True
# 12  0.01712   True
# 13  0.01767   True
# 14  0.01859   True
# 15  0.01981   True
# 16  0.02025   True
# 17  0.02151   True
# 18  0.02156   True
# 19  0.02336   True
# 20  0.02414   True
# 21  0.02424   True
# 22  0.02433   True
# 23  0.02579   True
# 24  0.02774   True
# 25  0.03116   True
# 26  0.03200   True
# 27  0.03211   True
# 28  0.03241   True
# 29  0.03321   True

# %%
query, df = get_predictions_df('uniprot:P22303', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                       name  \
# 0     3284      umls   C0151500                   Anticholinergic syndrome
# 1      224      umls   C0080274                          Urinary retention
# 2     1306      umls   C0028738                                  Nystagmus
# 3     2178      umls   C0030446                            Ileus paralytic
# 4      649      umls   C0004134                                     Ataxia
# 5      542      umls   C0235309                              Upset stomach
# 6     7542      umls   C0024517  Major depressive disorder, single episode
# 7     1072      umls   C0554976                               Bradyphrenia
# 8      672      umls   C0011168                                  Dysphagia
# 9       42      umls   C0037763                              Muscle spasms
# 10     371      umls   C0014549                       Grand mal convulsion
# 11    3273      umls   C0003635                                    Apraxia
# 12     316      umls   C2830004                                 Somnolence
# 13     730      umls   C0027066                                  Myoclonus
# 14    4934      umls   C0043515                 Zollinger-Ellison syndrome
# 15     540      umls   C0042075                     Urinary tract disorder
# 16     830      umls   C0235086            Muscle contractions involuntary
# 17    1961      umls   C0700361                         Emotional distress
# 18     602      umls   C0013362                                 Dysarthria
# 19    2009      umls   C0038220                         Status epilepticus
# 20     780      umls   C0086439                                Hypokinesia
# 21     186      umls   C0232495                       Abdominal pain lower
# 22    1742      umls   C0234369                                  Trembling
# 23     250      umls   C0020458                              Hyperhidrosis
# 24     347      umls   C0042023                                Pollakiuria
# 25    7845      umls   C0238111                    Lennox-Gastaut syndrome
# 26     591      umls   C0017168           Gastrooesophageal reflux disease
# 27    6399      umls   C0152159                          Uterine hypotonus
# 28     966      umls   C0014544                                   Epilepsy
# 29     822      umls   C1306341                          Mental disability
#
#         lor  novel
# 0   0.00501   True
# 1   0.01258   True
# 2   0.01408   True
# 3   0.01646   True
# 4   0.01728   True
# 5   0.01840   True
# 6   0.02222   True
# 7   0.02277   True
# 8   0.02371   True
# 9   0.02413   True
# 10  0.02594   True
# 11  0.03290   True
# 12  0.03764   True
# 13  0.03885   True
# 14  0.04173   True
# 15  0.04196   True
# 16  0.04328   True
# 17  0.04507   True
# 18  0.04679   True
# 19  0.04889   True
# 20  0.05026   True
# 21  0.05031   True
# 22  0.05250   True
# 23  0.05496   True
# 24  0.05525   True
# 25  0.05529   True
# 26  0.05620   True
# 27  0.05690   True
# 28  0.05780   True
# 29  0.05963   True

# %%
query, df = get_predictions_df('uniprot:Q9UBN7', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "12164",
#     "namespace": "uniprot",
#     "identifier": "Q9UBN7",
#     "name": "HDAC6_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0    17378  pubchem.compound   11671467
# 1     1616  pubchem.compound       1690
# 2    16237  pubchem.compound   10250490
# 3    14968  pubchem.compound    6914612
# 4    14559  pubchem.compound     456390
# 5    15758  pubchem.compound     854023
# 6    17357  pubchem.compound    9865515
# 7     1412  pubchem.compound      89594
# 8     6474  pubchem.compound      82146
# 9    14072  pubchem.compound     444732
# 10   15656  pubchem.compound   24752833
# 11    1914  pubchem.compound       1990
# 12   17066  pubchem.compound      10235
# 13    6368  pubchem.compound      64147
# 14   13990  pubchem.compound  131704272
# 15    4623  pubchem.compound     126941
# 16   10931  pubchem.compound     440210
# 17   13540  pubchem.compound     656948
# 18   17374  pubchem.compound      26248
# 19   12447  pubchem.compound     445555
# 20    7118  pubchem.compound    6442177
# 21   16775  pubchem.compound     146089
# 22    1148  pubchem.compound       6175
# 23   11132  pubchem.compound     448879
# 24    7102  pubchem.compound   73425383
# 25   13061  pubchem.compound      97032
# 26     589  pubchem.compound     221493
# 27   14248  pubchem.compound     439750
# 28     521  pubchem.compound        244
# 29    7294  pubchem.compound   11707110
#
#                                                  name      lor  novel
# 0                                        Fostamatinib  0.01494   True
# 1                                            AC1L1C0O  0.01709   True
# 2   5-CHLORO-N-(2-(4-(2-OXOPYRIDIN-1(2H)-YL)BENZAM...  0.02956   True
# 3   (1R,2R,3R,4S,5R)-4-(BENZYLAMINO)-5-(METHYLTHIO...  0.03387   True
# 4                                        Halofuginone  0.04130   True
# 5                                         Epibatidine  0.04134   True
# 6                                        Mocetinostat  0.04392   True
# 7                                            Nicotine  0.04611   True
# 8                                          Bexarotene  0.04937   True
# 9   7-[4-(Dimethylamino)Phenyl]-N-Hydroxy-4,6-Dime...  0.05546   True
# 10  N-((1R,2R)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO...  0.05616   True
# 11                               Acetohydroxamic acid  0.05993   True
# 12                                           Cytisine  0.06054   True
# 13                                     Valganciclovir  0.06338   True
# 14                                           CGP 4832  0.06466   True
# 15                                       Methotrexate  0.06594   True
# 16                   Bis(Adenosine)-5'-Pentaphosphate  0.06936   True
# 17                     Phosphorylated Dihydropteroate  0.06947   True
# 18                                          Diacerein  0.07129   True
# 19                2,5-Anhydroglucitol-1,6-Biphosphate  0.07417   True
# 20                                         Everolimus  0.07555   True
# 21               1,1,1-TRIFLUORO-3-(OCTYLTHIO)ACETONE  0.08089   True
# 22                                           Cytidine  0.09012   True
# 23                                N-Carbamyl-D-Valine  0.09696   True
# 24                                           Eribulin  0.10160   True
# 25           3,5,3',5'-Tetrachloro-Biphenyl-4,4'-Diol  0.10683   True
# 26                                        Cholic Acid  0.10703   True
# 27                                 N-Formylmethionine  0.11141   True
# 28                                     Benzyl alcohol  0.11422   True
# 29                                         Trametinib  0.11516   True

# %%
query, df = get_predictions_df("umls:C0030567", 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "k": 50,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     4517  pubchem.compound       6279
# 1     4970  pubchem.compound       4634
# 2     3629  pubchem.compound       3121
# 3     5617  pubchem.compound     443879
# 4     2573  pubchem.compound     644073
# 5     2044  pubchem.compound       2118
# 6     3697  pubchem.compound     667468
# 7     3691  pubchem.compound       3157
# 8     5753  pubchem.compound      60773
# 9     2199  pubchem.compound       2170
# 10    5192  pubchem.compound       5994
# 11    4499  pubchem.compound       3964
# 12    4712  pubchem.compound    3085218
# 13    6105  pubchem.compound    5311128
# 14    2935  pubchem.compound       2726
# 15    2173  pubchem.compound       2159
# 16    4886  pubchem.compound      13109
# 17    6474  pubchem.compound      82146
# 18    3488  pubchem.compound       2995
# 19    5101  pubchem.compound       5910
# 20    4506  pubchem.compound       4011
# 21    5907  pubchem.compound      12453
# 22    5610  pubchem.compound      36294
# 23    5974  pubchem.compound      23978
# 24    9515  pubchem.compound      60854
# 25    3914  pubchem.compound    1548968
# 26    6008  pubchem.compound      28486
# 27    5532  pubchem.compound       5401
# 28    6390  pubchem.compound     127151
# 29    7476  pubchem.compound   54682541
# 30    5191  pubchem.compound       4917
# 31    6632  pubchem.compound     125017
# 32    5479  pubchem.compound     445643
# 33    3187  pubchem.compound    1548953
# 34    6006  pubchem.compound      27993
# 35    6206  pubchem.compound      60198
# 36    5232  pubchem.compound       5002
# 37    1237  pubchem.compound    3001028
# 38    3547  pubchem.compound       3032
# 39    5814  pubchem.compound     969472
# 40    6295  pubchem.compound      60814
# 41    1991  pubchem.compound       2092
# 42    3850  pubchem.compound       3348
# 43    5197  pubchem.compound       4927
# 44    4687  pubchem.compound       4184
# 45    5731  pubchem.compound       5572
# 46    5391  pubchem.compound      68617
# 47    6755  pubchem.compound     156326
# 48    5697  pubchem.compound       5530
# 49    6162  pubchem.compound      57166
#
#                                             name      lor  novel
# 0                    Medroxyprogesterone acetate  0.00060   True
# 1                                     Oxybutynin  0.00060   True
# 2                                  Valproic Acid  0.00074   True
# 3                                    Tolterodine  0.00076   True
# 4                                  Buprenorphine  0.00077   True
# 5                                     Alprazolam  0.00078   True
# 6                                      Cidoxepin  0.00079   True
# 7                                      Doxazosin  0.00106   True
# 8                                   Valaciclovir  0.00116   True
# 9                                      Amoxapine  0.00120   True
# 10                                  Progesterone  0.00143   True
# 11                                      Loxapine  0.00146   True
# 12                                 Esmirtazapine  0.00165   True
# 13                                     Goserelin  0.00169   True
# 14                                Chlorpromazine  0.00169   True
# 15                                   Amisulpride  0.00175   True
# 16                                Levonorgestrel  0.00193   True
# 17                                    Bexarotene  0.00196   True
# 18                                   Desipramine  0.00204   True
# 19                                   Pilocarpine  0.00213   True
# 20                                   Maprotiline  0.00216   True
# 21                                      633-59-0  0.00218   True
# 22                                    Tobramycin  0.00248   True
# 23                                        Copper  0.00248   True
# 24                                   Ziprasidone  0.00252   True
# 25                                (S)-Fluoxetine  0.00254   True
# 26                                Lithium cation  0.00259   True
# 27                                     Terazosin  0.00268   True
# 28                                    Reboxetine  0.00272   True
# 29                                           NaN  0.00276   True
# 30                              Prochlorperazine  0.00279   True
# 31                                Desvenlafaxine  0.00281   True
# 32                                    Tacrolimus  0.00281   True
# 33                                  Enclomiphene  0.00287   True
# 34                                      AC1L1EDV  0.00299   True
# 35                                    Exemestane  0.00300   True
# 36                                    Quetiapine  0.00300   True
# 37                               Estrone sulfate  0.00302   True
# 38  {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00305   True
# 39                                   Eszopiclone  0.00307   True
# 40                    REMIFENTANIL HYDROCHLORIDE  0.00309   True
# 41                                     Alfuzosin  0.00321   True
# 42                                  Fexofenadine  0.00322   True
# 43                                  Promethazine  0.00333   True
# 44                                     Mianserin  0.00373   True
# 45                               Trihexyphenidyl  0.00376   True
# 46                                    Sertraline  0.00383   True
# 47                               SCHEMBL12856886  0.00417   True
# 48                               Tranylcypromine  0.00427   True
# 49                                           NaN  0.00429   True

# %%
results = []
for ind, row in df.iterrows():
    pmcid = []
    lit = query_europe_pmc(
        query_entity=row['name'],
        target_entities=[
            'umls:C0030567'
        ],
    )
    i = 0
    for x in lit:
        if i > 9:
            pmcid.append('... ect')
            lit.close()
            break
        pmcid.append(x['pmcid'])
        i+=1
    results.append((len(pmcid), pmcid))
df['co-occurance'] = results

# %%
df
# Out:
#    node_id         namespace identifier  \
# 0     4517  pubchem.compound       6279
# 1     4970  pubchem.compound       4634
# 2     3629  pubchem.compound       3121
# 3     5617  pubchem.compound     443879
# 4     2573  pubchem.compound     644073
# 5     2044  pubchem.compound       2118
# 6     3697  pubchem.compound     667468
# 7     3691  pubchem.compound       3157
# 8     5753  pubchem.compound      60773
# 9     2199  pubchem.compound       2170
# 10    5192  pubchem.compound       5994
# 11    4499  pubchem.compound       3964
# 12    4712  pubchem.compound    3085218
# 13    6105  pubchem.compound    5311128
# 14    2935  pubchem.compound       2726
# 15    2173  pubchem.compound       2159
# 16    4886  pubchem.compound      13109
# 17    6474  pubchem.compound      82146
# 18    3488  pubchem.compound       2995
# 19    5101  pubchem.compound       5910
# 20    4506  pubchem.compound       4011
# 21    5907  pubchem.compound      12453
# 22    5610  pubchem.compound      36294
# 23    5974  pubchem.compound      23978
# 24    9515  pubchem.compound      60854
# 25    3914  pubchem.compound    1548968
# 26    6008  pubchem.compound      28486
# 27    5532  pubchem.compound       5401
# 28    6390  pubchem.compound     127151
# 29    7476  pubchem.compound   54682541
# 30    5191  pubchem.compound       4917
# 31    6632  pubchem.compound     125017
# 32    5479  pubchem.compound     445643
# 33    3187  pubchem.compound    1548953
# 34    6006  pubchem.compound      27993
# 35    6206  pubchem.compound      60198
# 36    5232  pubchem.compound       5002
# 37    1237  pubchem.compound    3001028
# 38    3547  pubchem.compound       3032
# 39    5814  pubchem.compound     969472
# 40    6295  pubchem.compound      60814
# 41    1991  pubchem.compound       2092
# 42    3850  pubchem.compound       3348
# 43    5197  pubchem.compound       4927
# 44    4687  pubchem.compound       4184
# 45    5731  pubchem.compound       5572
# 46    5391  pubchem.compound      68617
# 47    6755  pubchem.compound     156326
# 48    5697  pubchem.compound       5530
# 49    6162  pubchem.compound      57166
#
#                                             name      lor  novel  \
# 0                    Medroxyprogesterone acetate  0.00060   True
# 1                                     Oxybutynin  0.00060   True
# 2                                  Valproic Acid  0.00074   True
# 3                                    Tolterodine  0.00076   True
# 4                                  Buprenorphine  0.00077   True
# 5                                     Alprazolam  0.00078   True
# 6                                      Cidoxepin  0.00079   True
# 7                                      Doxazosin  0.00106   True
# 8                                   Valaciclovir  0.00116   True
# 9                                      Amoxapine  0.00120   True
# 10                                  Progesterone  0.00143   True
# 11                                      Loxapine  0.00146   True
# 12                                 Esmirtazapine  0.00165   True
# 13                                     Goserelin  0.00169   True
# 14                                Chlorpromazine  0.00169   True
# 15                                   Amisulpride  0.00175   True
# 16                                Levonorgestrel  0.00193   True
# 17                                    Bexarotene  0.00196   True
# 18                                   Desipramine  0.00204   True
# 19                                   Pilocarpine  0.00213   True
# 20                                   Maprotiline  0.00216   True
# 21                                      633-59-0  0.00218   True
# 22                                    Tobramycin  0.00248   True
# 23                                        Copper  0.00248   True
# 24                                   Ziprasidone  0.00252   True
# 25                                (S)-Fluoxetine  0.00254   True
# 26                                Lithium cation  0.00259   True
# 27                                     Terazosin  0.00268   True
# 28                                    Reboxetine  0.00272   True
# 29                                           NaN  0.00276   True
# 30                              Prochlorperazine  0.00279   True
# 31                                Desvenlafaxine  0.00281   True
# 32                                    Tacrolimus  0.00281   True
# 33                                  Enclomiphene  0.00287   True
# 34                                      AC1L1EDV  0.00299   True
# 35                                    Exemestane  0.00300   True
# 36                                    Quetiapine  0.00300   True
# 37                               Estrone sulfate  0.00302   True
# 38  {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00305   True
# 39                                   Eszopiclone  0.00307   True
# 40                    REMIFENTANIL HYDROCHLORIDE  0.00309   True
# 41                                     Alfuzosin  0.00321   True
# 42                                  Fexofenadine  0.00322   True
# 43                                  Promethazine  0.00333   True
# 44                                     Mianserin  0.00373   True
# 45                               Trihexyphenidyl  0.00376   True
# 46                                    Sertraline  0.00383   True
# 47                               SCHEMBL12856886  0.00417   True
# 48                               Tranylcypromine  0.00427   True
# 49                                           NaN  0.00429   True
#
#                                          co-occurance
# 0   (11, [PMC2935455, PMC6483317, PMC3873843, PMC3...
# 1   (11, [PMC4857824, PMC6463833, PMC6493371, PMC3...
# 2   (11, [PMC4146011, PMC4269551, PMC2926634, PMC4...
# 3   (11, [PMC6463833, PMC3866282, PMC6493371, PMC1...
# 4   (11, [PMC2693002, PMC6513058, PMC5719065, PMC5...
# 5   (11, [PMC6494576, PMC4070603, PMC2823283, PMC6...
# 6                                             (0, [])
# 7   (11, [PMC4286669, PMC3858902, PMC2810806, PMC5...
# 8                                             (0, [])
# 9   (11, [PMC4355567, PMC5701274, PMC4442591, PMC5...
# 10  (11, [PMC2763283, PMC4396568, PMC3051156, PMC6...
# 11  (11, [PMC4442591, PMC6483410, NA, PMC5811827, ...
# 12                                            (0, [])
# 13  (7, [PMC5561408, PMC3181967, PMC6473290, PMC45...
# 14  (11, [PMC3271486, PMC4366389, PMC4118918, PMC6...
# 15  (11, [PMC6623749, PMC4364461, PMC6187640, PMC3...
# 16  (11, [PMC2766478, PMC4856424, PMC4403087, PMC3...
# 17  (11, [PMC4549399, PMC5644280, PMC6605427, PMC4...
# 18  (11, [PMC2680932, PMC4355567, PMC4279221, PMC4...
# 19  (11, [PMC6757526, PMC5214904, PMC5407108, PMC5...
# 20  (11, [PMC4355567, PMC2809336, PMC2822849, PMC5...
# 21                                            (0, [])
# 22  (11, [PMC5964511, PMC5743843, PMC5345890, PMC4...
# 23  (11, [PMC3941957, PMC3690345, PMC5400511, PMC3...
# 24  (11, [PMC6494156, PMC6398550, PMC4003829, PMC6...
# 25                                            (0, [])
# 26                                            (0, [])
# 27  (11, [PMC3411939, PMC3571677, PMC6463833, PMC3...
# 28                                            (0, [])
# 29                                            (0, [])
# 30  (11, [PMC6517141, PMC6483292, PMC6463839, PMC3...
# 31  (11, [PMC4169791, PMC3421081, PMC5719067, PMC5...
# 32  (11, [PMC5748183, PMC3156783, PMC4070603, PMC5...
# 33                                            (0, [])
# 34                                            (0, [])
# 35  (11, [NA, PMC3866684, PMC6157328, PMC5886305, ...
# 36  (11, [PMC4020145, PMC2675159, PMC4619813, PMC5...
# 37  (7, [PMC2835398, PMC6151497, PMC3866684, PMC48...
# 38                                            (0, [])
# 39  (11, [PMC6492503, PMC4020145, PMC4835298, PMC4...
# 40                                            (0, [])
# 41  (11, [PMC2721562, PMC3651657, PMC2823350, PMC6...
# 42  (11, [PMC2835398, PMC3965581, PMC2751796, PMC1...
# 43  (11, [PMC6517141, PMC3852816, PMC6483292, PMC6...
# 44  (11, [PMC4355567, PMC2823282, PMC6494576, PMC6...
# 45  (11, [PMC4803577, PMC3938056, PMC3275299, PMC2...
# 46  (11, [PMC6360927, PMC3699679, PMC3585317, PMC3...
# 47                                            (0, [])
# 48  (11, [PMC2849468, PMC19495, PMC3213739, PMC277...
# 49                                            (0, [])

# %%
df.to_csv(os.path.join(RESOURCES, 'parkinsons-chemicals.tsv'), sep='\t')

# %%
query, df = get_predictions_df('umls:C0242422', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "852",
#     "namespace": "umls",
#     "identifier": "C0242422",
#     "name": "Parkinsonism",
#     "entity_type": "phenotype"
#   },
#   "k": 50,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     6105  pubchem.compound    5311128
# 1     5617  pubchem.compound     443879
# 2     2573  pubchem.compound     644073
# 3     6474  pubchem.compound      82146
# 4     2199  pubchem.compound       2170
# 5     3697  pubchem.compound     667468
# 6     3547  pubchem.compound       3032
# 7     4506  pubchem.compound       4011
# 8     2044  pubchem.compound       2118
# 9     5101  pubchem.compound       5910
# 10    6206  pubchem.compound      60198
# 11    4970  pubchem.compound       4634
# 12    5814  pubchem.compound     969472
# 13    6449  pubchem.compound     444031
# 14    5512  pubchem.compound    2733526
# 15    3488  pubchem.compound       2995
# 16    5753  pubchem.compound      60773
# 17    2173  pubchem.compound       2159
# 18    1237  pubchem.compound    3001028
# 19    5151  pubchem.compound      54687
# 20    4886  pubchem.compound      13109
# 21    2223  pubchem.compound       2182
# 22    2422  pubchem.compound       2351
# 23    6390  pubchem.compound     127151
# 24    6784  pubchem.compound    5310966
# 25    5610  pubchem.compound      36294
# 26    5898  pubchem.compound      11125
# 27    9515  pubchem.compound      60854
# 28    6192  pubchem.compound      60146
# 29   14671  pubchem.compound   11154555
# 30    2638  pubchem.compound       2519
# 31    6415  pubchem.compound      71158
# 32    3599  pubchem.compound      10531
# 33    4712  pubchem.compound    3085218
# 34    4499  pubchem.compound       3964
# 35   17624  pubchem.compound      16741
# 36   16088  pubchem.compound    1190625
# 37    7476  pubchem.compound   54682541
# 38    4474  pubchem.compound       3939
# 39    5805  pubchem.compound      60857
# 40    2177  pubchem.compound       2160
# 41    4874  pubchem.compound       6230
# 42    4256  pubchem.compound       3696
# 43    4109  pubchem.compound    5284566
# 44    7216  pubchem.compound    9865528
# 45    1381  pubchem.compound        937
# 46    3674  pubchem.compound    1150567
# 47    6006  pubchem.compound      27993
# 48    4687  pubchem.compound       4184
# 49    6632  pubchem.compound     125017
#
#                                                  name      lor  novel
# 0                                           Goserelin  0.00073   True
# 1                                         Tolterodine  0.00105   True
# 2                                       Buprenorphine  0.00141   True
# 3                                          Bexarotene  0.00185   True
# 4                                           Amoxapine  0.00188   True
# 5                                           Cidoxepin  0.00215   True
# 6        {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00243   True
# 7                                         Maprotiline  0.00253   True
# 8                                          Alprazolam  0.00283   True
# 9                                         Pilocarpine  0.00296   True
# 10                                         Exemestane  0.00337   True
# 11                                         Oxybutynin  0.00341   True
# 12                                        Eszopiclone  0.00357   True
# 13                                        Darifenacin  0.00361   True
# 14                                          Tamoxifen  0.00377   True
# 15                                        Desipramine  0.00398   True
# 16                                       Valaciclovir  0.00411   True
# 17                                        Amisulpride  0.00440   True
# 18                                    Estrone sulfate  0.00476   True
# 19                                        Pravastatin  0.00479   True
# 20                                     Levonorgestrel  0.00479   True
# 21                                         Anagrelide  0.00506   True
# 22                                           Bepridil  0.00506   True
# 23                                         Reboxetine  0.00520   True
# 24                                        Varenicline  0.00539   True
# 25                                         Tobramycin  0.00558   True
# 26                                  Lithium carbonate  0.00562   True
# 27                                        Ziprasidone  0.00562   True
# 28                       (S)-Tamsulosin Hydrochloride  0.00586   True
# 29                                        Cariprazine  0.00632   True
# 30                                           Caffeine  0.00634   True
# 31                                        Acamprosate  0.00642   True
# 32                                  Dihydroergotamine  0.00679   True
# 33                                      Esmirtazapine  0.00717   True
# 34                                           Loxapine  0.00747   True
# 35                           Phenethyl Isothiocyanate  0.00760   True
# 36  N,N-DIETHYL-2-[(2-THIENYLCARBONYL)AMINO]-4,5,6...  0.00771   True
# 37                                                NaN  0.00825   True
# 38                                  Lithium hydroxide  0.00837   True
# 39                                       Zolmitriptan  0.00851   True
# 40                                      Amitriptyline  0.00863   True
# 41                                     Norethisterone  0.00874   True
# 42                                         Imipramine  0.00888   True
# 43                                        Granisetron  0.00910   True
# 44                                         Mirabegron  0.00926   True
# 45                                         nicotinate  0.00937   True
# 46  1-BENZYL-4-[(5,6-DIMETHOXY-1-INDANON-2-YL)METH...  0.00954   True
# 47                                           AC1L1EDV  0.01007   True
# 48                                          Mianserin  0.01017   True
# 49                                     Desvenlafaxine  0.01018   True

# %%
query, df = get_predictions_df('pubchem.compound:5095', 'phenotype')
print(json.dumps(query, indent=2))
df
#PMID: 29241812
# Out:
# {
#   "entity": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                    name  \
# 0      291      umls   C0085605                         Hepatic failure
# 1     1139      umls   C0853034  Blood creatine phosphokinase increased
# 2     1484      umls   C0014518              Toxic epidermal necrolysis
# 3      763      umls   C0038325                Stevens-Johnson syndrome
# 4      536      umls   C0037317                       Sleep disturbance
# 5      273      umls   C0026858                    Musculoskeletal pain
# 6      870      umls   C0424000                       Suicidal ideation
# 7     1317      umls   C0022658                             Nephropathy
# 8      862      umls   C0392156                               Akathisia
# 9      585      umls   C0687133                        Drug interaction
# 10     626      umls   C0018834                               Heartburn
# 11    1104      umls   C0024115                           Lung disorder
# 12    1106      umls   C0006849                        Oral candidiasis
# 13    3030      umls   C0010068                  Coronary heart disease
# 14    6143      umls   C0694549            Community acquired pneumonia
# 15    7667      umls   C0008677                      Bronchitis chronic
# 16    1912      umls   C0085602                              Polydipsia
# 17    1117      umls   C0242429                             Throat sore
# 18     903      umls   C0574067                         Cough increased
# 19    1467      umls   C0002878                      Haemolytic anaemia
# 20     623      umls   C0014742                     Erythema multiforme
# 21    2698      umls   C0020545               Renovascular hypertension
# 22    1138      umls   C0151576        Creatine phosphokinase increased
# 23    1072      umls   C0554976                            Bradyphrenia
# 24    6249      umls   C0036337                Schizoaffective disorder
# 25    1817      umls   C0242339                           Dyslipidaemia
# 26     676      umls   C0011606                  Dermatitis exfoliative
# 27    1094      umls   C1291077                      Abdominal bloating
# 28     331      umls   C0013144                              Drowsiness
# 29    1497      umls   C0011609                           Drug eruption
#
#         lor  novel
# 0   0.00023   True
# 1   0.00030   True
# 2   0.00037   True
# 3   0.00045   True
# 4   0.00045   True
# 5   0.00051   True
# 6   0.00052   True
# 7   0.00057   True
# 8   0.00066   True
# 9   0.00068   True
# 10  0.00076   True
# 11  0.00082   True
# 12  0.00084   True
# 13  0.00088   True
# 14  0.00090   True
# 15  0.00091   True
# 16  0.00093   True
# 17  0.00096   True
# 18  0.00118   True
# 19  0.00123   True
# 20  0.00152   True
# 21  0.00157   True
# 22  0.00176   True
# 23  0.00177   True
# 24  0.00178   True
# 25  0.00185   True
# 26  0.00187   True
# 27  0.00193   True
# 28  0.00194   True
# 29  0.00196   True

# %%
r = predictor.find_new_relation(
    source_id='2071', #Amantadine
    target_id='2248', #Parkinson's disease
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "2071",
#     "namespace": "pubchem.compound",
#     "identifier": "2130",
#     "name": "Amantadine",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00478
# }

# %%
r = predictor.find_new_relation(
    source_id='5346', #Ropinirole
    target_id='1348', #Restless legs syndrome
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1348",
#     "namespace": "umls",
#     "identifier": "C0035258",
#     "name": "Restless legs syndrome",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00667
# }

# %%
r = predictor.find_new_relation(
    source_id='3627', #Disulfiram
    target_id='2318', #Malignant melanoma
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "3627",
#     "namespace": "pubchem.compound",
#     "identifier": "3117",
#     "name": "Disulfiram",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2318",
#     "namespace": "umls",
#     "identifier": "C0025202",
#     "name": "Malignant melanoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.51121
# }

# %%
r = predictor.find_new_relation(
    source_id='17528', #Brigatinib
    target_id='5148', #Colorectal cancer
)
print(json.dumps(r, indent=2))
#PMID: 31410188
# Out:
# {
#   "source": {
#     "node_id": "17528",
#     "namespace": "uniprot",
#     "identifier": "Q99640",
#     "name": "PMYT1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "5148",
#     "namespace": "umls",
#     "identifier": "C1527249",
#     "name": "Colorectal cancer",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.8214
# }

# %%
r = predictor.find_new_relation(
    source_id='6995', #dasatinib
    target_id='1179', #Diffuse large B-cell lymphoma
)
print(json.dumps(r, indent=2))
#PMID: 31383760
# Out:
# {
#   "source": {
#     "node_id": "6995",
#     "namespace": "pubchem.compound",
#     "identifier": "3062316",
#     "name": "Dasatinib",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1179",
#     "namespace": "umls",
#     "identifier": "C0079744",
#     "name": "Diffuse large B-cell lymphoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.83577
# }

# %%
r = predictor.find_new_relation(
    source_id='5265', #ribavirin
    target_id='947', #Candida infection
)
print(json.dumps(r, indent=2))
#PMID: 31307986
# Out:
# {
#   "source": {
#     "node_id": "5265",
#     "namespace": "pubchem.compound",
#     "identifier": "37542",
#     "name": "Ribavirin",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "947",
#     "namespace": "umls",
#     "identifier": "C0006840",
#     "name": "Candida infection",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.12888
# }
