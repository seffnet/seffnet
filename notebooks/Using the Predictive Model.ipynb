# %% [markdown]
# # Using the Prediction Model
#
# ## Environment

# %%
import getpass
import json
import os
import sys
import time

import pandas as pd
from tqdm import tqdm_notebook as tqdm

from seffnet.constants import (
    DEFAULT_EMBEDDINGS_PATH, DEFAULT_GRAPH_PATH,
    DEFAULT_MAPPING_PATH, DEFAULT_PREDICTIVE_MODEL_PATH,
    RESOURCES
)
from seffnet.literature import query_europe_pmc

# %%
print(sys.version)
# Out:
# 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]

# %%
print(time.asctime())
# Out:
# Fri Jan  3 12:12:03 2020

# %%
print(getpass.getuser())
# Out:
# aldis

# %% [markdown]
# # Loading the Data

# %%
from seffnet.default_predictor import predictor

# %%
print(f"""Loaded default predictor using paths:

embeddings: {DEFAULT_EMBEDDINGS_PATH}
graph:      {DEFAULT_GRAPH_PATH}
model:      {DEFAULT_PREDICTIVE_MODEL_PATH}
mapping:    {DEFAULT_MAPPING_PATH}
""")
# Out:
# Loaded default predictor using paths:
#
# embeddings: c:\users\aldis\documents\github\seffnet\resources\embeddings\0812_weighted_node2vec_emb.embeddings
# graph:      c:\users\aldis\documents\github\seffnet\resources\basic_graphs\fullgraph_with_chemsim.edgelist
# model:      c:\users\aldis\documents\github\seffnet\resources\predictive_models\0812_weighted_node2vec_predictive_model.pkl
# mapping:    c:\users\aldis\documents\github\seffnet\resources\mapping\fullgraph_nodes_mapping.tsv

# %% [markdown]
# # Examples of different kinds of predictions with literature evidence

# %% [markdown]
# ## side effect - target association

# %%
r = predictor.find_new_relation(
    source_name='EGFR_HUMAN',
    target_name='Papulopustular rash',
)
print(json.dumps(r, indent=2))
#PMID: 18165622
# Out:
# {
#   "source": {
#     "node_id": "9587",
#     "namespace": "uniprot",
#     "identifier": "P00533",
#     "name": "EGFR_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "6791",
#     "namespace": "umls",
#     "identifier": "C2609319",
#     "name": "Papulopustular rash",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.62433
# }

# %%
r = predictor.find_new_relation(
    source_id='9451', # Histamine receptor H1
    target_id='331', # Drowsiness
)
print(json.dumps(r, indent=2))
#PMID: 26626077
# Out:
# {
#   "source": {
#     "node_id": "9451",
#     "namespace": "uniprot",
#     "identifier": "P35367",
#     "name": "HRH1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "331",
#     "namespace": "umls",
#     "identifier": "C0013144",
#     "name": "Drowsiness",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.08185
# }

# %%
r = predictor.find_new_relation(
    source_id='9325', # SC6A2
    target_id='56', # Tachycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "9325",
#     "namespace": "uniprot",
#     "identifier": "P23975",
#     "name": "SC6A2_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "56",
#     "namespace": "umls",
#     "identifier": "C0039231",
#     "name": "Tachycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.52279
# }

# %%
r = predictor.find_new_relation(
    source_id='8670', # ACES_HUMAN
    target_id='309', # Bradycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "309",
#     "namespace": "umls",
#     "identifier": "C0428977",
#     "name": "Bradycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.85649
# }

# %% [markdown]
# ## drug- side effect association

# %%
r = predictor.find_new_relation(
    source_id='3534',  # diazepam
    target_id='670',  # Libido decreased
)
print(json.dumps(r, indent=2))
#PMID: 29888057
# Out:
# {
#   "source": {
#     "node_id": "3534",
#     "namespace": "pubchem.compound",
#     "identifier": "3016",
#     "name": "Diazepam",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "670",
#     "namespace": "umls",
#     "identifier": "C0011124",
#     "name": "Libido decreased",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00453
# }

# %%
r = predictor.find_new_relation(
    source_id='1148',  # Cytarabine 
    target_id='1149',  # Anaemia megaloblastic
)
print(json.dumps(r, indent=2))
# PMID: 23157436
# Out:
# {
#   "source": {
#     "node_id": "1148",
#     "namespace": "pubchem.compound",
#     "identifier": "6175",
#     "name": "Cytidine",
#     "entity_type": "experimental drug"
#   },
#   "target": {
#     "node_id": "1149",
#     "namespace": "umls",
#     "identifier": "C0002888",
#     "name": "Anaemia megaloblastic",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.22571
# }

# %% [markdown]
# ## drug-target association

# %%
r = predictor.find_new_relation(
    source_id='14672',  # Sertindole 
    target_id='9350',   # CHRM1 receptor
)
print(json.dumps(r, indent=2))
# PMID: 29942259
# Out:
# {
#   "source": {
#     "node_id": "14672",
#     "namespace": "pubchem.compound",
#     "identifier": "60149",
#     "name": "Sertindole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN",
#     "entity_type": "target"
#   },
#   "lor": 0.01543
# }

# %% [markdown]
# # Example of predicting relations using node2vec model and embeddings

# %%
def get_predictions_df(curie, results_type=None):
    results = predictor.find_new_relations(
        node_curie=curie,
        results_type=results_type,
        k=50,
    )
    results_df = pd.DataFrame(results['predictions'])
    results_df = results_df[['node_id', 'namespace', 'identifier', 'name', 'lor', 'novel']]
    return results['query'], results_df

# %%
query, df = get_predictions_df('pubchem.compound:2159', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2173",
#     "namespace": "pubchem.compound",
#     "identifier": "2159",
#     "name": "Amisulpride",
#     "entity_type": "approved drug"
#   },
#   "k": 50,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                          name  \
# 0      816      umls   C0232461                            Increased appetite
# 1      655      umls   C0006145                               Breast disorder
# 2      678      umls   C0012569                                      Diplopia
# 3     1385      umls   C0015732                           Faecal incontinence
# 4      797      umls   C0338831                                         Mania
# 5      351      umls   C0085633                                   Mood swings
# 6      539      umls   C0042024                          Urinary incontinence
# 7      652      umls   C0853193                            Bipolar I disorder
# 8     1732      umls   C0037822                               Speech disorder
# 9     2876      umls   C0041747                          Unintended pregnancy
# 10     649      umls   C0004134                                        Ataxia
# 11    8068      umls   C0425979                                   Nulliparous
# 12     535      umls   C0031212                          Personality disorder
# 13     626      umls   C0018834                                     Heartburn
# 14    1062      umls   C0497327                                      Dementia
# 15     987      umls   C0025323                                   Menorrhagia
# 16     108      umls   C0036508                        Seborrhoeic dermatitis
# 17     980      umls   C0023533                                    Leukorrhea
# 18    1391      umls   C0019270                                        Hernia
# 19     995      umls   C0034150                                       Purpura
# 20    2460      umls   C0162316                       Iron deficiency anaemia
# 21     303      umls   C0392025                           Enlargement abdomen
# 22     827      umls   C0234458                               Abnormal dreams
# 23     790      umls   C0151611                 Electroencephalogram abnormal
# 24     371      umls   C0014549                          Grand mal convulsion
# 25     647      umls   C0002622                                       Amnesia
# 26      41      umls   C0023218                   Cramps of lower extremities
# 27     599      umls   C0085632                                        Apathy
# 28     894      umls   C0547030                            Visual disturbance
# 29    6136      umls   C0474395                            Increased activity
# 30      87      umls   C0003537                                       Aphasia
# 31     718      umls   C0021177                              Libido increased
# 32     821      umls   C0233632                             Thinking abnormal
# 33     944      umls   C0005940                                 Bone disorder
# 34     568      umls   C0018939                                Blood disorder
# 35     352      umls   C0233472                               Affect lability
# 36    1961      umls   C0700361                            Emotional distress
# 37     552      umls   C0085628                                        Stupor
# 38     799      umls   C0151836                             Paranoid reaction
# 39    1303      umls   C0001925                                   Albuminuria
# 40    2299      umls   C0039520                                 Tenosynovitis
# 41    1141      umls   C3257803                                  Tearing eyes
# 42    2140      umls   C0151878                Electrocardiogram QT prolonged
# 43     429      umls   C0030794                                   Pelvic pain
# 44     717      umls   C0021141  Inappropriate antidiuretic hormone secretion
# 45     640      umls   C0033975                            Psychotic disorder
# 46    4934      umls   C0043515                    Zollinger-Ellison syndrome
# 47    1868      umls   C3203358                               Hypoventilation
# 48    1074      umls   C0575081                              Gait disturbance
# 49     213      umls   C0027051                         Myocardial infarction
#
#         lor  novel
# 0   0.00006   True
# 1   0.00009   True
# 2   0.00019   True
# 3   0.00023   True
# 4   0.00028   True
# 5   0.00032   True
# 6   0.00036   True
# 7   0.00036   True
# 8   0.00038   True
# 9   0.00043   True
# 10  0.00044   True
# 11  0.00047   True
# 12  0.00054   True
# 13  0.00055   True
# 14  0.00057   True
# 15  0.00059   True
# 16  0.00061   True
# 17  0.00062   True
# 18  0.00067   True
# 19  0.00071   True
# 20  0.00072   True
# 21  0.00073   True
# 22  0.00084   True
# 23  0.00084   True
# 24  0.00085   True
# 25  0.00087   True
# 26  0.00091   True
# 27  0.00091   True
# 28  0.00094   True
# 29  0.00101   True
# 30  0.00102   True
# 31  0.00102   True
# 32  0.00106   True
# 33  0.00107   True
# 34  0.00111   True
# 35  0.00112   True
# 36  0.00114   True
# 37  0.00115   True
# 38  0.00115   True
# 39  0.00116   True
# 40  0.00117   True
# 41  0.00120   True
# 42  0.00121   True
# 43  0.00122   True
# 44  0.00126   True
# 45  0.00127   True
# 46  0.00133   True
# 47  0.00139   True
# 48  0.00142   True
# 49  0.00143   True

# %%
query, df = get_predictions_df('pubchem.compound:4585', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "4915",
#     "namespace": "pubchem.compound",
#     "identifier": "4585",
#     "name": "Olanzapine",
#     "entity_type": "approved drug"
#   },
#   "k": 50,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                       name  \
# 0      238      umls   C0344232                             Vision blurred
# 1     1391      umls   C0019270                                     Hernia
# 2     1892      umls   C0041105                                    Trismus
# 3     1156      umls   C0018991                                 Hemiplegia
# 4      774      umls   C0043387                                    Yawning
# 5     1822      umls   C0525045                         Affective disorder
# 6     2460      umls   C0162316                    Iron deficiency anaemia
# 7      538      umls   C0040435                             Tooth disorder
# 8     1029      umls   C0234238                                       Ache
# 9     1657      umls   C0151754    Lactic dehydrogenase activity increased
# 10    1396      umls   C0023066                               Laryngospasm
# 11    4633      umls   C0751495                           Partial seizures
# 12     734      umls   C0028084                                  Nightmare
# 13     870      umls   C0424000                          Suicidal ideation
# 14    1836      umls   C0013415                         Dysthymic disorder
# 15      87      umls   C0003537                                    Aphasia
# 16     817      umls   C0233414                   Disturbance in attention
# 17     950      umls   C0007787                 Transient ischaemic attack
# 18     168      umls   C0043144                                   Wheezing
# 19     337      umls   C0036454                                    Scotoma
# 20     750      umls   C0034880                                Hyperacusis
# 21    7541      umls   C0018379                             Feeling guilty
# 22    7542      umls   C0024517  Major depressive disorder, single episode
# 23     641      umls   C0151889                              Hyperreflexia
# 24    1141      umls   C3257803                               Tearing eyes
# 25     735      umls   C0028734                                   Nocturia
# 26    2592      umls   C0424091                         Decreased interest
# 27    1660      umls   C0151888                               Hyporeflexia
# 28     924      umls   C0878773                         Hypertonic bladder
# 29    1417      umls   C0019825                                 Hoarseness
# 30    2445      umls   C0235901                   Lacrimation abnormal NOS
# 31     898      umls   C0549622                         Sexual dysfunction
# 32     782      umls   C0086769                               Panic attack
# 33    2175      umls   C1457883                        Aggressive reaction
# 34     834      umls   C0235198                       Cerebration impaired
# 35    1252      umls   C0022650                         Calculus of kidney
# 36     807      umls   C0152517                            Viral diarrhoea
# 37     626      umls   C0018834                                  Heartburn
# 38     818      umls   C0233477                                  Dysphoria
# 39    6259      umls   C0233633                      Bradypsychic response
# 40     684      umls   C0014394                                   Enuresis
# 41     116      umls   C0041582                                      Ulcer
# 42    4944      umls   C0520904                       Nausea postoperative
# 43    1696      umls   C2364111                                    Ageusia
# 44     437      umls   C0033575                         Prostatic disorder
# 45     909      umls   C0699744                              Ear infection
# 46     663      umls   C0009319                                    Colitis
# 47    2299      umls   C0039520                              Tenosynovitis
# 48    4046      umls   C0011882                        Diabetic neuropathy
# 49      74      umls   C0522055                 Electrocardiogram abnormal
#
#         lor  novel
# 0   0.00015   True
# 1   0.00017   True
# 2   0.00024   True
# 3   0.00024   True
# 4   0.00028   True
# 5   0.00032   True
# 6   0.00038   True
# 7   0.00041   True
# 8   0.00042   True
# 9   0.00042   True
# 10  0.00048   True
# 11  0.00051   True
# 12  0.00052   True
# 13  0.00053   True
# 14  0.00054   True
# 15  0.00055   True
# 16  0.00056   True
# 17  0.00057   True
# 18  0.00066   True
# 19  0.00070   True
# 20  0.00072   True
# 21  0.00072   True
# 22  0.00073   True
# 23  0.00075   True
# 24  0.00075   True
# 25  0.00078   True
# 26  0.00079   True
# 27  0.00082   True
# 28  0.00084   True
# 29  0.00087   True
# 30  0.00088   True
# 31  0.00089   True
# 32  0.00091   True
# 33  0.00094   True
# 34  0.00103   True
# 35  0.00107   True
# 36  0.00114   True
# 37  0.00117   True
# 38  0.00118   True
# 39  0.00123   True
# 40  0.00129   True
# 41  0.00136   True
# 42  0.00136   True
# 43  0.00137   True
# 44  0.00137   True
# 45  0.00137   True
# 46  0.00141   True
# 47  0.00141   True
# 48  0.00141   True
# 49  0.00141   True

# %%
query, df = get_predictions_df('uniprot:P08172', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "9429",
#     "namespace": "uniprot",
#     "identifier": "P08172",
#     "name": "ACM2_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 50,
#   "type": "phenotype"
# }
#    node_id namespace identifier                      name      lor  novel
# 0      302      umls   C1269683          Major depression  0.00162   True
# 1     2146      umls   C0234133   Extrapyramidal symptoms  0.00218   True
# 2     1141      umls   C3257803              Tearing eyes  0.00258   True
# 3      238      umls   C0344232            Vision blurred  0.00372   True
# 4     1062      umls   C0497327                  Dementia  0.00374   True
# 5     2879      umls   C0026650         Movement disorder  0.00438   True
# 6     1836      umls   C0013415        Dysthymic disorder  0.00472   True
# 7      352      umls   C0233472           Affect lability  0.00640   True
# 8      817      umls   C0233414  Disturbance in attention  0.00675   True
# 9      816      umls   C0232461        Increased appetite  0.00678   True
# 10    1385      umls   C0015732       Faecal incontinence  0.00694   True
# 11     780      umls   C0086439               Hypokinesia  0.00701   True
# 12    1297      umls   C0018794               Block heart  0.00729   True
# 13     103      umls   C0027769               Nervousness  0.00828   True
# 14     925      umls   C0917799               Hypersomnia  0.00851   True
# 15     675      umls   C0011551         Depersonalisation  0.00902   True
# 16    7541      umls   C0018379            Feeling guilty  0.00939   True
# 17      61      umls   C0043094          Weight increased  0.00945   True
# 18    1822      umls   C0525045        Affective disorder  0.00965   True
# 19     870      umls   C0424000         Suicidal ideation  0.00977   True
# 20     647      umls   C0002622                   Amnesia  0.01006   True
# 21    3494      umls   C0028840       Ocular hypertension  0.01079   True
# 22       5      umls   C0002418                 Amblyopia  0.01083   True
# 23    1303      umls   C0001925               Albuminuria  0.01125   True
# 24     700      umls   C0017605    Angle closure glaucoma  0.01152   True
# 25    2180      umls   C0152198    Accommodation disorder  0.01208   True
# 26     779      umls   C0086132        Depressive symptom  0.01250   True
# 27    6667      umls   C0343065        Urticaria physical  0.01274   True
# 28    1272      umls   C0014457              Eosinophilia  0.01289   True
# 29     987      umls   C0025323               Menorrhagia  0.01298   True
# 30     678      umls   C0012569                  Diplopia  0.01321   True
# 31     686      umls   C0014724                Eructation  0.01329   True
# 32     398      umls   C0423153               Lacrimation  0.01339   True
# 33     535      umls   C0031212      Personality disorder  0.01340   True
# 34     503      umls   C3665386           Abnormal vision  0.01375   True
# 35     300      umls   C0267596        Rectal haemorrhage  0.01380   True
# 36     395      umls   C0037036   Salivary hypersecretion  0.01418   True
# 37     346      umls   C0085606       Micturition urgency  0.01432   True
# 38    1388      umls   C0017601                  Glaucoma  0.01454   True
# 39     728      umls   C0026837           Muscle rigidity  0.01460   True
# 40     394      umls   C0036104                Salivation  0.01463   True
# 41     833      umls   C1262141        Poor quality sleep  0.01467   True
# 42      47      umls   C0030252              Palpitations  0.01485   True
# 43     285      umls   C0038990                  Sweating  0.01486   True
# 44    6259      umls   C0233633     Bradypsychic response  0.01519   True
# 45     913      umls   C0853348            Arthropod bite  0.01613   True
# 46    1892      umls   C0041105                   Trismus  0.01631   True
# 47      18      umls   C0009806              Constipation  0.01643   True
# 48     862      umls   C0392156                 Akathisia  0.01653   True
# 49     908      umls   C0686347        Tardive dyskinesia  0.01669   True

# %%
query, df = get_predictions_df('uniprot:P08588', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8733",
#     "namespace": "uniprot",
#     "identifier": "P08588",
#     "name": "ADRB1_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 50,
#   "type": "phenotype"
# }
#    node_id namespace identifier                              name      lor  \
# 0     4348      umls   C0232201                      Sinus rhythm  0.00886
# 1     1952      umls   C0232197              Cardiac fibrillation  0.01189
# 2       93      umls   C0018799                  Cardiac disorder  0.01216
# 3      206      umls   C0018790                    Cardiac arrest  0.01395
# 4     3494      umls   C0028840               Ocular hypertension  0.01452
# 5      266      umls   C0018801                   Cardiac failure  0.01567
# 6      354      umls   C0151636         Ventricular extrasystoles  0.01721
# 7     1714      umls   C0004239                    Atrial flutter  0.02010
# 8     1325      umls   C0857121                      Hypertensive  0.02139
# 9      238      umls   C0344232                    Vision blurred  0.02171
# 10    7709      umls   C0340288            Stable angina pectoris  0.02228
# 11     444      umls   C0039240      Supraventricular tachycardia  0.02235
# 12    8163      umls   C0242407       Hyperkinetic heart syndrome  0.02235
# 13     690      umls   C0016385                   Cardiac flutter  0.02328
# 14    2774      umls   C0035067             Renal artery stenosis  0.02746
# 15    1297      umls   C0018794                       Block heart  0.02802
# 16     995      umls   C0034150                           Purpura  0.02818
# 17    7642      umls   C0857070       Chronic open angle glaucoma  0.02820
# 18     910      umls   C0700184                 Throat irritation  0.03120
# 19    1102      umls   C0002962                   Angina pectoris  0.03156
# 20     271      umls   C0020651           Orthostatic hypotension  0.03251
# 21    2834      umls   C0010054  Arteriosclerosis coronary artery  0.03451
# 22    7769      umls   C0428776                     Cardiac index  0.03477
# 23    1388      umls   C0017601                          Glaucoma  0.03492
# 24      76      umls   C0917801                          Insomnia  0.03606
# 25    5509      umls   C0011881              Diabetic nephropathy  0.03657
# 26    1121      umls   C0546884                      Hypovolaemia  0.03861
# 27      59      umls   C0042571                           Vertigo  0.03878
# 28      49      umls   C0030554                      Paraesthesia  0.03920
# 29     336      umls   C0033036    Supraventricular extrasystoles  0.04020
# 30     330      umls   C0004245            Atrioventricular block  0.04243
# 31    3600      umls   C0010073             Arteriospasm coronary  0.04666
# 32    3692      umls   C0085580            Essential hypertension  0.04696
# 33     291      umls   C0085605                   Hepatic failure  0.04793
# 34     331      umls   C0013144                        Drowsiness  0.04820
# 35      56      umls   C0039231                       Tachycardia  0.04824
# 36     503      umls   C3665386                   Abnormal vision  0.04896
# 37      12      umls   C0004238               Atrial fibrillation  0.05199
# 38    1646      umls   C0036980                 Cardiogenic shock  0.05236
# 39    2479      umls   C0235462                    Anginal attack  0.05249
# 40     348      umls   C0085612            Ventricular arrhythmia  0.05329
# 41     382      umls   C1956346           Coronary artery disease  0.05388
# 42     734      umls   C0028084                         Nightmare  0.05545
# 43    4826      umls   C0002963                 Prinzmetal angina  0.05588
# 44    1396      umls   C0023066                      Laryngospasm  0.05660
# 45     214      umls   C0948089           Acute coronary syndrome  0.05740
# 46      47      umls   C0030252                      Palpitations  0.05817
# 47     345      umls   C0042514           Ventricular tachycardia  0.05909
# 48       3      umls   C0000737                    Abdominal pain  0.05959
# 49    1133      umls   C1961112            Decompensation cardiac  0.06037
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True
# 30   True
# 31   True
# 32   True
# 33   True
# 34   True
# 35   True
# 36   True
# 37   True
# 38   True
# 39   True
# 40   True
# 41   True
# 42   True
# 43   True
# 44   True
# 45   True
# 46   True
# 47   True
# 48   True
# 49   True

# %%
query, df = get_predictions_df('uniprot:P22303', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 50,
#   "type": "phenotype"
# }
#    node_id namespace identifier                          name      lor  novel
# 0     3284      umls   C0151500      Anticholinergic syndrome  0.12628   True
# 1      294      umls   C0232487          Abdominal discomfort  0.14619   True
# 2      539      umls   C0042024          Urinary incontinence  0.18802   True
# 3      822      umls   C1306341             Mental disability  0.19613   True
# 4      894      umls   C0547030            Visual disturbance  0.20704   True
# 5      732      umls   C0027796                     Neuralgia  0.21594   True
# 6      248      umls   C0236075           Menopausal symptoms  0.24063   True
# 7      987      umls   C0025323                   Menorrhagia  0.25108   True
# 8       42      umls   C0037763                 Muscle spasms  0.25592   True
# 9     2896      umls   C0085635                     Photopsia  0.25932   True
# 10     628      umls   C0038358                 Gastric ulcer  0.26200   True
# 11     535      umls   C0031212          Personality disorder  0.26509   True
# 12     224      umls   C0080274             Urinary retention  0.27160   True
# 13     626      umls   C0018834                     Heartburn  0.28333   True
# 14       7      umls   C0003123                      Anorexia  0.28579   True
# 15    1001      umls   C0042133             Uterine leiomyoma  0.28769   True
# 16    1385      umls   C0015732           Faecal incontinence  0.29313   True
# 17    4934      umls   C0043515    Zollinger-Ellison syndrome  0.29382   True
# 18      33      umls   C0019080                   Haemorrhage  0.29621   True
# 19    2145      umls   C0231303                      Distress  0.29934   True
# 20      87      umls   C0003537                       Aphasia  0.30539   True
# 21     179      umls   C0039070                       Syncope  0.31837   True
# 22     672      umls   C0011168                     Dysphagia  0.32044   True
# 23     300      umls   C0267596            Rectal haemorrhage  0.33594   True
# 24    7824      umls   C0221013         Systemic mastocytosis  0.34197   True
# 25     266      umls   C0018801               Cardiac failure  0.34354   True
# 26       4      umls   C0687713         Gastrointestinal pain  0.34371   True
# 27     542      umls   C0235309                 Upset stomach  0.35235   True
# 28    1539      umls   C0006384           Bundle branch block  0.35421   True
# 29    7541      umls   C0018379                Feeling guilty  0.35957   True
# 30    3048      umls   C0028754                       Obesity  0.36492   True
# 31     345      umls   C0042514       Ventricular tachycardia  0.36711   True
# 32     618      umls   C0017181  Gastrointestinal haemorrhage  0.37178   True
# 33      61      umls   C0043094              Weight increased  0.37197   True
# 34     351      umls   C0085633                   Mood swings  0.37325   True
# 35     594      umls   C0438717       Transaminases increased  0.37357   True
# 36     925      umls   C0917799                   Hypersomnia  0.38177   True
# 37    2193      umls   C0234987            Dizziness postural  0.38288   True
# 38    1303      umls   C0001925                   Albuminuria  0.38409   True
# 39     462      umls   C0235063        Respiratory depression  0.38454   True
# 40    2759      umls   C0035317           Retinal haemorrhage  0.38620   True
# 41      60      umls   C0042963                      Vomiting  0.38650   True
# 42     590      umls   C0014869            Reflux esophagitis  0.38651   True
# 43    1334      umls   C0021359                   Infertility  0.38804   True
# 44     735      umls   C0028734                      Nocturia  0.39299   True
# 45     602      umls   C0013362                    Dysarthria  0.39551   True
# 46    1306      umls   C0028738                     Nystagmus  0.39575   True
# 47     169      umls   C0231218                       Malaise  0.39576   True
# 48     352      umls   C0233472               Affect lability  0.39821   True
# 49    1348      umls   C0035258        Restless legs syndrome  0.40836   True

# %%
query, df = get_predictions_df('uniprot:Q9UBN7', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "12164",
#     "namespace": "uniprot",
#     "identifier": "Q9UBN7",
#     "name": "HDAC6_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 50,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     5829  pubchem.compound       5978
# 1    10931  pubchem.compound     440210
# 2     1465  pubchem.compound       1054
# 3    17357  pubchem.compound    9865515
# 4     6856  pubchem.compound     216326
# 5      589  pubchem.compound     221493
# 6    13540  pubchem.compound     656948
# 7     1616  pubchem.compound       1690
# 8     6213  pubchem.compound      60668
# 9    12447  pubchem.compound     445555
# 10   13990  pubchem.compound  131704272
# 11    1914  pubchem.compound       1990
# 12    7286  pubchem.compound   11626560
# 13   16224  pubchem.compound       3547
# 14    5002  pubchem.compound       4673
# 15   17052  pubchem.compound       3689
# 16   11132  pubchem.compound     448879
# 17     521  pubchem.compound        244
# 18    7268  pubchem.compound   11167602
# 19   15656  pubchem.compound   24752833
# 20     321  pubchem.compound        175
# 21    4623  pubchem.compound     126941
# 22    6474  pubchem.compound      82146
# 23    5531  pubchem.compound     452548
# 24    4958  pubchem.compound       4609
# 25    6578  pubchem.compound    5481350
# 26    6530  pubchem.compound    3011155
# 27    5577  pubchem.compound       5426
# 28    6780  pubchem.compound     166548
# 29    6308  pubchem.compound     446556
# 30   12611  pubchem.compound       3710
# 31   17066  pubchem.compound      10235
# 32    7102  pubchem.compound   73425383
# 33    2538  pubchem.compound       2471
# 34    5198  pubchem.compound       4932
# 35    5590  pubchem.compound      60648
# 36       1  pubchem.compound      10918
# 37      80  pubchem.compound        119
# 38   15912  pubchem.compound       1881
# 39    5801  pubchem.compound      35370
# 40   11153  pubchem.compound      65562
# 41   13070  pubchem.compound     657043
# 42   12457  pubchem.compound     449409
# 43    6373  pubchem.compound      64987
# 44   12373  pubchem.compound    6915836
# 45   10869  pubchem.compound     165390
# 46    6386  pubchem.compound      65628
# 47   11222  pubchem.compound     446795
# 48   12748  pubchem.compound     100016
# 49    6676  pubchem.compound     468595
#
#                                                  name      lor  novel
# 0                                         Vincristine  0.02040   True
# 1                    Bis(Adenosine)-5'-Pentaphosphate  0.03094   True
# 2                                          Pyridoxine  0.03736   True
# 3                                        Mocetinostat  0.03816   True
# 4                                        Lenalidomide  0.03886   True
# 5                                         Cholic Acid  0.04168   True
# 6                      Phosphorylated Dihydropteroate  0.05937   True
# 7                                            AC1L1C0O  0.06055   True
# 8                                 ETOPOSIDE PHOSPHATE  0.06134   True
# 9                 2,5-Anhydroglucitol-1,6-Biphosphate  0.06145   True
# 10                                           CGP 4832  0.07315   True
# 11                               Acetohydroxamic acid  0.07753   True
# 12                                         Crizotinib  0.07899   True
# 13                                            Fasudil  0.09487   True
# 14                                         57248-88-1  0.09513   True
# 15                                         Ifenprodil  0.09711   True
# 16                                N-Carbamyl-D-Valine  0.09795   True
# 17                                     Benzyl alcohol  0.09845   True
# 18                                        Regorafenib  0.10046   True
# 19  N-((1R,2R)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO...  0.10329   True
# 20                                            Acetate  0.10522   True
# 21                                       Methotrexate  0.11265   True
# 22                                         Bexarotene  0.11438   True
# 23                                         Teniposide  0.11579   True
# 24                                    NCGC00167798-01  0.13880   True
# 25                               Tenofovir disoproxil  0.14388   True
# 26                                         Nelarabine  0.14571   True
# 27                                        Thalidomide  0.14716   True
# 28                                      Anidulafungin  0.14822   True
# 29                                         Pemetrexed  0.15231   True
# 30  4-(1-Benzyl-3-Carbamoylmethyl-2-Methyl-1h-Indo...  0.15571   True
# 31                                           Cytisine  0.15899   True
# 32                                           Eribulin  0.15900   True
# 33                                         Bumetanide  0.16375   True
# 34                                        Propafenone  0.16438   True
# 35                                          Tiagabine  0.16537   True
# 36  (3-Carboxy-2-(R)-Hydroxy-Propyl)-Trimethyl-Amm...  0.16865   True
# 37                            gamma-Aminobutyric acid  0.16949   True
# 38  7-(1-ETHYL-PROPYL)-7H-PYRROLO-[3,2-F]QUINAZOLI...  0.17131   True
# 39                                         Zidovudine  0.17157   True
# 40                            Cordycepin Triphosphate  0.17200   True
# 41  2-(Beta-D-Glucopyranosyl)-5-Methyl-1,3,4-Oxadi...  0.17281   True
# 42                      Phenyl-Uridine-5'-Diphosphate  0.17391   True
# 43                                          Apropovir  0.17991   True
# 44                      Uracil arabinose-3'-phosphate  0.18482   True
# 45                             Methacrylyl-Coenzyme A  0.18554   True
# 46                                       Bendamustine  0.18767   True
# 47                 N6-Benzyl Adenosine-5'-Diphosphate  0.18780   True
# 48                                         Zebularine  0.18792   True
# 49                                       Posaconazole  0.18993   True

# %%
query, df = get_predictions_df("umls:C0030567", 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "k": 50,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     5590  pubchem.compound      60648
# 1     3674  pubchem.compound    1150567
# 2     6158  pubchem.compound      55480
# 3     6417  pubchem.compound     175805
# 4     4946  pubchem.compound    3034010
# 5     3547  pubchem.compound       3032
# 6     7107  pubchem.compound    9838022
# 7     6656  pubchem.compound     129228
# 8     5931  pubchem.compound      16362
# 9     6316  pubchem.compound      60853
# 10    6030  pubchem.compound      34312
# 11    2173  pubchem.compound       2159
# 12    3712  pubchem.compound       3168
# 13    2497  pubchem.compound       2441
# 14    4795  pubchem.compound       4409
# 15    4030  pubchem.compound       3446
# 16    6301  pubchem.compound      60834
# 17    7315  pubchem.compound   16129629
# 18    7027  pubchem.compound    5329102
# 19    5391  pubchem.compound      68617
# 20    5646  pubchem.compound      33741
# 21    4712  pubchem.compound    3085218
# 22    5284  pubchem.compound       5070
# 23    3914  pubchem.compound    1548968
# 24    3691  pubchem.compound       3157
# 25    5898  pubchem.compound      11125
# 26    6755  pubchem.compound     156326
# 27    5198  pubchem.compound       4932
# 28    5809  pubchem.compound       5732
# 29    2365  pubchem.compound      44602
# 30    3171  pubchem.compound       2789
# 31    5606  pubchem.compound      60947
# 32    4506  pubchem.compound       4011
# 33    5002  pubchem.compound       4673
# 34    6128  pubchem.compound      54373
# 35    3629  pubchem.compound       3121
# 36    6582  pubchem.compound     121892
# 37    4132  pubchem.compound       3519
# 38    6432  pubchem.compound      71360
# 39    6206  pubchem.compound      60198
# 40    6188  pubchem.compound    5284583
# 41    5340  pubchem.compound       5078
# 42    2712  pubchem.compound       2554
# 43    2935  pubchem.compound       2726
# 44    1148  pubchem.compound       6175
# 45   17624  pubchem.compound      16741
# 46    4515  pubchem.compound       4036
# 47    2772  pubchem.compound       2585
# 48    6415  pubchem.compound      71158
# 49   13061  pubchem.compound      97032
#
#                                                  name      lor  novel
# 0                                           Tiagabine  0.00087   True
# 1   1-BENZYL-4-[(5,6-DIMETHOXY-1-INDANON-2-YL)METH...  0.00104   True
# 2                                            AC1L1J67  0.00181   True
# 3                                         Ropivacaine  0.00183   True
# 4                                            Orlistat  0.00204   True
# 5        {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00229   True
# 6                                          Tapentadol  0.00232   True
# 7                                          Rufinamide  0.00294   True
# 8                                            Pimozide  0.00313   True
# 9                                         138982-67-9  0.00358   True
# 10                                      Oxcarbazepine  0.00374   True
# 11                                        Amisulpride  0.00391   True
# 12                                         Droperidol  0.00394   True
# 13                                         Bromazepam  0.00440   True
# 14                                         Nabumetone  0.00470   True
# 15                                         Gabapentin  0.00474   True
# 16                           DULOXETINE HYDROCHLORIDE  0.00489   True
# 17                                         DAPTOMYCIN  0.00492   True
# 18                                          Sunitinib  0.00495   True
# 19                                         Sertraline  0.00505   True
# 20                                           Tramadol  0.00507   True
# 21                                      Esmirtazapine  0.00511   True
# 22                                           Riluzole  0.00515   True
# 23                                     (S)-Fluoxetine  0.00528   True
# 24                                          Doxazosin  0.00533   True
# 25                                  Lithium carbonate  0.00534   True
# 26                                    SCHEMBL12856886  0.00543   True
# 27                                        Propafenone  0.00557   True
# 28                                           Zolpidem  0.00579   True
# 29                                         Arbaclofen  0.00581   True
# 30                                           Clobazam  0.00589   True
# 31                                          Tirofiban  0.00593   True
# 32                                        Maprotiline  0.00598   True
# 33                                         57248-88-1  0.00602   True
# 34                                 Octreotide acetate  0.00611   True
# 35                                      Valproic Acid  0.00636   True
# 36                                          Ezogabine  0.00638   True
# 37                                         Guanfacine  0.00649   True
# 38                                        Iloperidone  0.00651   True
# 39                                         Exemestane  0.00662   True
# 40                                      Levetiracetam  0.00667   True
# 41                                        Rizatriptan  0.00675   True
# 42                                      Carbamazepine  0.00700   True
# 43                                     Chlorpromazine  0.00712   True
# 44                                           Cytidine  0.00712   True
# 45                           Phenethyl Isothiocyanate  0.00716   True
# 46                                           Meclomen  0.00722   True
# 47                                         Carvedilol  0.00738   True
# 48                                        Acamprosate  0.00739   True
# 49           3,5,3',5'-Tetrachloro-Biphenyl-4,4'-Diol  0.00744   True

# %%
results = []
for ind, row in df.iterrows():
    pmcid = []
    lit = query_europe_pmc(
        query_entity=row['name'],
        target_entities=[
            'umls:C0030567'
        ],
    )
    i = 0
    for x in lit:
        if i > 7:
            pmcid.append('... ect')
            lit.close()
            break
        pmcid.append(x['pmcid'])
        i+=1
    results.append((len(pmcid), pmcid))
df['co-occurance'] = results

# %%
df
# Out:
#    node_id         namespace identifier  \
# 0     5590  pubchem.compound      60648
# 1     3674  pubchem.compound    1150567
# 2     6158  pubchem.compound      55480
# 3     6417  pubchem.compound     175805
# 4     4946  pubchem.compound    3034010
# 5     3547  pubchem.compound       3032
# 6     7107  pubchem.compound    9838022
# 7     6656  pubchem.compound     129228
# 8     5931  pubchem.compound      16362
# 9     6316  pubchem.compound      60853
# 10    6030  pubchem.compound      34312
# 11    2173  pubchem.compound       2159
# 12    3712  pubchem.compound       3168
# 13    2497  pubchem.compound       2441
# 14    4795  pubchem.compound       4409
# 15    4030  pubchem.compound       3446
# 16    6301  pubchem.compound      60834
# 17    7315  pubchem.compound   16129629
# 18    7027  pubchem.compound    5329102
# 19    5391  pubchem.compound      68617
# 20    5646  pubchem.compound      33741
# 21    4712  pubchem.compound    3085218
# 22    5284  pubchem.compound       5070
# 23    3914  pubchem.compound    1548968
# 24    3691  pubchem.compound       3157
# 25    5898  pubchem.compound      11125
# 26    6755  pubchem.compound     156326
# 27    5198  pubchem.compound       4932
# 28    5809  pubchem.compound       5732
# 29    2365  pubchem.compound      44602
# 30    3171  pubchem.compound       2789
# 31    5606  pubchem.compound      60947
# 32    4506  pubchem.compound       4011
# 33    5002  pubchem.compound       4673
# 34    6128  pubchem.compound      54373
# 35    3629  pubchem.compound       3121
# 36    6582  pubchem.compound     121892
# 37    4132  pubchem.compound       3519
# 38    6432  pubchem.compound      71360
# 39    6206  pubchem.compound      60198
# 40    6188  pubchem.compound    5284583
# 41    5340  pubchem.compound       5078
# 42    2712  pubchem.compound       2554
# 43    2935  pubchem.compound       2726
# 44    1148  pubchem.compound       6175
# 45   17624  pubchem.compound      16741
# 46    4515  pubchem.compound       4036
# 47    2772  pubchem.compound       2585
# 48    6415  pubchem.compound      71158
# 49   13061  pubchem.compound      97032
#
#                                                  name      lor  novel  \
# 0                                           Tiagabine  0.00087   True
# 1   1-BENZYL-4-[(5,6-DIMETHOXY-1-INDANON-2-YL)METH...  0.00104   True
# 2                                            AC1L1J67  0.00181   True
# 3                                         Ropivacaine  0.00183   True
# 4                                            Orlistat  0.00204   True
# 5        {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00229   True
# 6                                          Tapentadol  0.00232   True
# 7                                          Rufinamide  0.00294   True
# 8                                            Pimozide  0.00313   True
# 9                                         138982-67-9  0.00358   True
# 10                                      Oxcarbazepine  0.00374   True
# 11                                        Amisulpride  0.00391   True
# 12                                         Droperidol  0.00394   True
# 13                                         Bromazepam  0.00440   True
# 14                                         Nabumetone  0.00470   True
# 15                                         Gabapentin  0.00474   True
# 16                           DULOXETINE HYDROCHLORIDE  0.00489   True
# 17                                         DAPTOMYCIN  0.00492   True
# 18                                          Sunitinib  0.00495   True
# 19                                         Sertraline  0.00505   True
# 20                                           Tramadol  0.00507   True
# 21                                      Esmirtazapine  0.00511   True
# 22                                           Riluzole  0.00515   True
# 23                                     (S)-Fluoxetine  0.00528   True
# 24                                          Doxazosin  0.00533   True
# 25                                  Lithium carbonate  0.00534   True
# 26                                    SCHEMBL12856886  0.00543   True
# 27                                        Propafenone  0.00557   True
# 28                                           Zolpidem  0.00579   True
# 29                                         Arbaclofen  0.00581   True
# 30                                           Clobazam  0.00589   True
# 31                                          Tirofiban  0.00593   True
# 32                                        Maprotiline  0.00598   True
# 33                                         57248-88-1  0.00602   True
# 34                                 Octreotide acetate  0.00611   True
# 35                                      Valproic Acid  0.00636   True
# 36                                          Ezogabine  0.00638   True
# 37                                         Guanfacine  0.00649   True
# 38                                        Iloperidone  0.00651   True
# 39                                         Exemestane  0.00662   True
# 40                                      Levetiracetam  0.00667   True
# 41                                        Rizatriptan  0.00675   True
# 42                                      Carbamazepine  0.00700   True
# 43                                     Chlorpromazine  0.00712   True
# 44                                           Cytidine  0.00712   True
# 45                           Phenethyl Isothiocyanate  0.00716   True
# 46                                           Meclomen  0.00722   True
# 47                                         Carvedilol  0.00738   True
# 48                                        Acamprosate  0.00739   True
# 49           3,5,3',5'-Tetrachloro-Biphenyl-4,4'-Diol  0.00744   True
#
#                                          co-occurance
# 0   (9, [PMC5318686, PMC6141625, PMC4931873, PMC34...
# 1                                             (0, [])
# 2                                             (0, [])
# 3   (9, [PMC2386465, PMC3172332, PMC3168353, PMC64...
# 4           (3, [PMC3283822, PMC3006492, PMC5274590])
# 5                                             (0, [])
# 6                                   (1, [PMC6145352])
# 7                                             (0, [])
# 8   (9, [PMC2772366, PMC2483942, PMC2947884, PMC65...
# 9                                             (0, [])
# 10  (9, [PMC5759952, PMC4931873, PMC6863370, PMC40...
# 11  (9, [PMC6623749, PMC4364461, PMC6187640, PMC31...
# 12  (9, [PMC6483292, PMC6463839, PMC6517141, PMC64...
# 13  (9, [PMC6360927, PMC6177143, PMC6483292, PMC47...
# 14  (9, [PMC3308767, PMC3561897, PMC4422696, PMC51...
# 15  (9, [PMC6599858, PMC2770914, PMC3499716, PMC57...
# 16  (7, [PMC4169791, PMC6178768, PMC6039401, PMC43...
# 17  (9, [PMC4023767, PMC5722777, PMC3811277, PMC69...
# 18  (9, [PMC6493018, PMC5729903, PMC4290715, PMC67...
# 19  (9, [PMC3585317, PMC3699679, PMC3372723, PMC63...
# 20  (9, [PMC4594269, PMC4904595, PMC4777264, PMC28...
# 21                                            (0, [])
# 22  (9, [PMC6493865, PMC6921406, PMC6209077, PMC15...
# 23                                            (0, [])
# 24  (9, [PMC4286669, PMC3858902, PMC2810806, PMC53...
# 25  (9, [PMC3171956, PMC3543487, PMC181115, NA, PM...
# 26                                            (0, [])
# 27  (9, [PMC4503722, PMC6555565, PMC6324729, PMC53...
# 28  (9, [PMC4886078, PMC2762721, PMC4603066, PMC66...
# 29                                            (0, [])
# 30  (9, [PMC4931873, PMC6095775, PMC5569602, PMC63...
# 31  (9, [PMC6453219, PMC5822470, PMC4790257, PMC61...
# 32  (9, [PMC4355567, PMC2809336, PMC2822849, PMC57...
# 33                                            (0, [])
# 34                                            (0, [])
# 35  (9, [PMC4146011, PMC4269551, PMC2926634, PMC42...
# 36  (6, [PMC3711947, PMC3373146, PMC5073917, PMC48...
# 37  (9, [PMC4471292, PMC4261148, PMC5719066, PMC33...
# 38  (9, [PMC6863369, PMC4336923, PMC6863380, PMC44...
# 39  (9, [NA, PMC3866684, PMC6157328, PMC5886305, P...
# 40  (9, [PMC4931873, PMC4322303, PMC6360927, PMC57...
# 41  (8, [PMC5709272, PMC4758397, PMC4460611, PMC38...
# 42  (9, [PMC3853540, PMC556232, PMC5759952, PMC651...
# 43  (9, [PMC3271486, PMC4366389, PMC4118918, PMC64...
# 44  (9, [PMC5710031, PMC2900914, PMC3962138, PMC37...
# 45  (9, [PMC4596548, PMC5914347, PMC5037733, PMC39...
# 46                                            (0, [])
# 47  (9, [PMC6881195, PMC3195115, PMC4212306, NA, P...
# 48  (9, [PMC2268999, PMC5149585, PMC4075088, PMC32...
# 49                                            (0, [])

# %%
df.to_csv(os.path.join(RESOURCES, 'parkinsons-chemicals.tsv'), sep='\t')

# %%
query, df = get_predictions_df('umls:C0242422', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "852",
#     "namespace": "umls",
#     "identifier": "C0242422",
#     "name": "Parkinsonism",
#     "entity_type": "phenotype"
#   },
#   "k": 50,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     6105  pubchem.compound    5311128
# 1     5617  pubchem.compound     443879
# 2     2573  pubchem.compound     644073
# 3     6474  pubchem.compound      82146
# 4     2199  pubchem.compound       2170
# 5     3697  pubchem.compound     667468
# 6     3547  pubchem.compound       3032
# 7     4506  pubchem.compound       4011
# 8     2044  pubchem.compound       2118
# 9     5101  pubchem.compound       5910
# 10    6206  pubchem.compound      60198
# 11    4970  pubchem.compound       4634
# 12    5814  pubchem.compound     969472
# 13    6449  pubchem.compound     444031
# 14    5512  pubchem.compound    2733526
# 15    3488  pubchem.compound       2995
# 16    5753  pubchem.compound      60773
# 17    2173  pubchem.compound       2159
# 18    1237  pubchem.compound    3001028
# 19    5151  pubchem.compound      54687
# 20    4886  pubchem.compound      13109
# 21    2223  pubchem.compound       2182
# 22    2422  pubchem.compound       2351
# 23    6390  pubchem.compound     127151
# 24    6784  pubchem.compound    5310966
# 25    5610  pubchem.compound      36294
# 26    5898  pubchem.compound      11125
# 27    9515  pubchem.compound      60854
# 28    6192  pubchem.compound      60146
# 29   14671  pubchem.compound   11154555
# 30    2638  pubchem.compound       2519
# 31    6415  pubchem.compound      71158
# 32    3599  pubchem.compound      10531
# 33    4712  pubchem.compound    3085218
# 34    4499  pubchem.compound       3964
# 35   17624  pubchem.compound      16741
# 36   16088  pubchem.compound    1190625
# 37    7476  pubchem.compound   54682541
# 38    4474  pubchem.compound       3939
# 39    5805  pubchem.compound      60857
# 40    2177  pubchem.compound       2160
# 41    4874  pubchem.compound       6230
# 42    4256  pubchem.compound       3696
# 43    4109  pubchem.compound    5284566
# 44    7216  pubchem.compound    9865528
# 45    1381  pubchem.compound        937
# 46    3674  pubchem.compound    1150567
# 47    6006  pubchem.compound      27993
# 48    4687  pubchem.compound       4184
# 49    6632  pubchem.compound     125017
#
#                                                  name      lor  novel
# 0                                           Goserelin  0.00073   True
# 1                                         Tolterodine  0.00105   True
# 2                                       Buprenorphine  0.00141   True
# 3                                          Bexarotene  0.00185   True
# 4                                           Amoxapine  0.00188   True
# 5                                           Cidoxepin  0.00215   True
# 6        {2-[(2,6-dichlorophenyl)amino]phenyl}acetate  0.00243   True
# 7                                         Maprotiline  0.00253   True
# 8                                          Alprazolam  0.00283   True
# 9                                         Pilocarpine  0.00296   True
# 10                                         Exemestane  0.00337   True
# 11                                         Oxybutynin  0.00341   True
# 12                                        Eszopiclone  0.00357   True
# 13                                        Darifenacin  0.00361   True
# 14                                          Tamoxifen  0.00377   True
# 15                                        Desipramine  0.00398   True
# 16                                       Valaciclovir  0.00411   True
# 17                                        Amisulpride  0.00440   True
# 18                                    Estrone sulfate  0.00476   True
# 19                                        Pravastatin  0.00479   True
# 20                                     Levonorgestrel  0.00479   True
# 21                                         Anagrelide  0.00506   True
# 22                                           Bepridil  0.00506   True
# 23                                         Reboxetine  0.00520   True
# 24                                        Varenicline  0.00539   True
# 25                                         Tobramycin  0.00558   True
# 26                                  Lithium carbonate  0.00562   True
# 27                                        Ziprasidone  0.00562   True
# 28                       (S)-Tamsulosin Hydrochloride  0.00586   True
# 29                                        Cariprazine  0.00632   True
# 30                                           Caffeine  0.00634   True
# 31                                        Acamprosate  0.00642   True
# 32                                  Dihydroergotamine  0.00679   True
# 33                                      Esmirtazapine  0.00717   True
# 34                                           Loxapine  0.00747   True
# 35                           Phenethyl Isothiocyanate  0.00760   True
# 36  N,N-DIETHYL-2-[(2-THIENYLCARBONYL)AMINO]-4,5,6...  0.00771   True
# 37                                                NaN  0.00825   True
# 38                                  Lithium hydroxide  0.00837   True
# 39                                       Zolmitriptan  0.00851   True
# 40                                      Amitriptyline  0.00863   True
# 41                                     Norethisterone  0.00874   True
# 42                                         Imipramine  0.00888   True
# 43                                        Granisetron  0.00910   True
# 44                                         Mirabegron  0.00926   True
# 45                                         nicotinate  0.00937   True
# 46  1-BENZYL-4-[(5,6-DIMETHOXY-1-INDANON-2-YL)METH...  0.00954   True
# 47                                           AC1L1EDV  0.01007   True
# 48                                          Mianserin  0.01017   True
# 49                                     Desvenlafaxine  0.01018   True

# %%
query, df = get_predictions_df('pubchem.compound:5095', 'phenotype')
print(json.dumps(query, indent=2))
df
#PMID: 29241812
# Out:
# {
#   "entity": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                    name  \
# 0      291      umls   C0085605                         Hepatic failure
# 1     1139      umls   C0853034  Blood creatine phosphokinase increased
# 2     1484      umls   C0014518              Toxic epidermal necrolysis
# 3      763      umls   C0038325                Stevens-Johnson syndrome
# 4      536      umls   C0037317                       Sleep disturbance
# 5      273      umls   C0026858                    Musculoskeletal pain
# 6      870      umls   C0424000                       Suicidal ideation
# 7     1317      umls   C0022658                             Nephropathy
# 8      862      umls   C0392156                               Akathisia
# 9      585      umls   C0687133                        Drug interaction
# 10     626      umls   C0018834                               Heartburn
# 11    1104      umls   C0024115                           Lung disorder
# 12    1106      umls   C0006849                        Oral candidiasis
# 13    3030      umls   C0010068                  Coronary heart disease
# 14    6143      umls   C0694549            Community acquired pneumonia
# 15    7667      umls   C0008677                      Bronchitis chronic
# 16    1912      umls   C0085602                              Polydipsia
# 17    1117      umls   C0242429                             Throat sore
# 18     903      umls   C0574067                         Cough increased
# 19    1467      umls   C0002878                      Haemolytic anaemia
# 20     623      umls   C0014742                     Erythema multiforme
# 21    2698      umls   C0020545               Renovascular hypertension
# 22    1138      umls   C0151576        Creatine phosphokinase increased
# 23    1072      umls   C0554976                            Bradyphrenia
# 24    6249      umls   C0036337                Schizoaffective disorder
# 25    1817      umls   C0242339                           Dyslipidaemia
# 26     676      umls   C0011606                  Dermatitis exfoliative
# 27    1094      umls   C1291077                      Abdominal bloating
# 28     331      umls   C0013144                              Drowsiness
# 29    1497      umls   C0011609                           Drug eruption
#
#         lor  novel
# 0   0.00023   True
# 1   0.00030   True
# 2   0.00037   True
# 3   0.00045   True
# 4   0.00045   True
# 5   0.00051   True
# 6   0.00052   True
# 7   0.00057   True
# 8   0.00066   True
# 9   0.00068   True
# 10  0.00076   True
# 11  0.00082   True
# 12  0.00084   True
# 13  0.00088   True
# 14  0.00090   True
# 15  0.00091   True
# 16  0.00093   True
# 17  0.00096   True
# 18  0.00118   True
# 19  0.00123   True
# 20  0.00152   True
# 21  0.00157   True
# 22  0.00176   True
# 23  0.00177   True
# 24  0.00178   True
# 25  0.00185   True
# 26  0.00187   True
# 27  0.00193   True
# 28  0.00194   True
# 29  0.00196   True

# %%
r = predictor.find_new_relation(
    source_id='2071', #Amantadine
    target_id='2248', #Parkinson's disease
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "2071",
#     "namespace": "pubchem.compound",
#     "identifier": "2130",
#     "name": "Amantadine",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00478
# }

# %%
r = predictor.find_new_relation(
    source_id='5346', #Ropinirole
    target_id='1348', #Restless legs syndrome
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1348",
#     "namespace": "umls",
#     "identifier": "C0035258",
#     "name": "Restless legs syndrome",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.00667
# }

# %%
r = predictor.find_new_relation(
    source_id='3627', #Disulfiram
    target_id='2318', #Malignant melanoma
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "3627",
#     "namespace": "pubchem.compound",
#     "identifier": "3117",
#     "name": "Disulfiram",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2318",
#     "namespace": "umls",
#     "identifier": "C0025202",
#     "name": "Malignant melanoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.51121
# }

# %%
r = predictor.find_new_relation(
    source_id='17528', #Brigatinib
    target_id='5148', #Colorectal cancer
)
print(json.dumps(r, indent=2))
#PMID: 31410188
# Out:
# {
#   "source": {
#     "node_id": "17528",
#     "namespace": "uniprot",
#     "identifier": "Q99640",
#     "name": "PMYT1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "5148",
#     "namespace": "umls",
#     "identifier": "C1527249",
#     "name": "Colorectal cancer",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.8214
# }

# %%
r = predictor.find_new_relation(
    source_id='6995', #dasatinib
    target_id='1179', #Diffuse large B-cell lymphoma
)
print(json.dumps(r, indent=2))
#PMID: 31383760
# Out:
# {
#   "source": {
#     "node_id": "6995",
#     "namespace": "pubchem.compound",
#     "identifier": "3062316",
#     "name": "Dasatinib",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1179",
#     "namespace": "umls",
#     "identifier": "C0079744",
#     "name": "Diffuse large B-cell lymphoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.83577
# }

# %%
r = predictor.find_new_relation(
    source_id='5265', #ribavirin
    target_id='947', #Candida infection
)
print(json.dumps(r, indent=2))
#PMID: 31307986
# Out:
# {
#   "source": {
#     "node_id": "5265",
#     "namespace": "pubchem.compound",
#     "identifier": "37542",
#     "name": "Ribavirin",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "947",
#     "namespace": "umls",
#     "identifier": "C0006840",
#     "name": "Candida infection",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.12888
# }
