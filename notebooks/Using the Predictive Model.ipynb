# %% [markdown]
# # Using the Prediction Model
#
# ## Environment

# %%
import getpass
import json
import os
import sys
import time

import pandas as pd

from se_kge.constants import (
    DEFAULT_EMBEDDINGS_PATH, DEFAULT_GRAPH_PATH,
    DEFAULT_MAPPING_PATH, DEFAULT_MODEL_PATH,
)

# %%
print(sys.version)
# Out:
# 3.7.2 (tags/v3.7.2:9a3ffc0492, Dec 23 2018, 23:09:28) [MSC v.1916 64 bit (AMD64)]

# %%
print(time.asctime())
# Out:
# Mon Sep  9 11:55:23 2019

# %%
print(getpass.getuser())
# Out:
# RanaAldisi

# %% [markdown]
# # Loading the Data

# %%
from se_kge.default_predictor import predictor

# %%
print(f"""Loaded default predictor using paths:

embeddings: {DEFAULT_EMBEDDINGS_PATH}
graph:      {DEFAULT_GRAPH_PATH}
model:      {DEFAULT_MODEL_PATH}
mapping:    {DEFAULT_MAPPING_PATH}
""")
# Out:
# Loaded default predictor using paths:
#
# embeddings: c:\users\rana aldisi\documents\github\se_kge\resources\predictive_model\0809_line_emb.embeddings
# graph:      c:\users\rana aldisi\documents\github\se_kge\resources\basic_graphs\fullgraph_with_chemsim.edgelist
# model:      c:\users\rana aldisi\documents\github\se_kge\resources\predictive_model\0809_line_model.pkl
# mapping:    c:\users\rana aldisi\documents\github\se_kge\resources\mapping\fullgraph_nodes_mapping.tsv

# %% [markdown]
# # Examples of different kinds of predictions with literature evidence

# %% [markdown]
# ## side effect - target association

# %%
r = predictor.find_new_relation(
    source_name='EGFR_HUMAN',
    target_name='Papulopustular rash',
)
print(json.dumps(r, indent=2))
#PMID: 18165622
# Out:
# {
#   "source": {
#     "node_id": "9587",
#     "namespace": "uniprot",
#     "identifier": "P00533",
#     "name": "EGFR_HUMAN"
#   },
#   "target": {
#     "node_id": "6791",
#     "namespace": "umls",
#     "identifier": "C2609319",
#     "name": "Papulopustular rash"
#   },
#   "p": 0.996,
#   "mlp": 0.002
# }

# %%
r = predictor.find_new_relation(
    source_id='9451', # Histamine receptor H1
    target_id='331', # Drowsiness
)
print(json.dumps(r, indent=2))
#PMID: 26626077
# Out:
# {
#   "source": {
#     "node_id": "9451",
#     "namespace": "uniprot",
#     "identifier": "P35367",
#     "name": "HRH1_HUMAN"
#   },
#   "target": {
#     "node_id": "331",
#     "namespace": "umls",
#     "identifier": "C0013144",
#     "name": "Drowsiness"
#   },
#   "p": 0.934,
#   "mlp": 0.029
# }

# %%
r = predictor.find_new_relation(
    source_id='9325', # SC6A2
    target_id='56', # Tachycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "9325",
#     "namespace": "uniprot",
#     "identifier": "P23975",
#     "name": "SC6A2_HUMAN"
#   },
#   "target": {
#     "node_id": "56",
#     "namespace": "umls",
#     "identifier": "C0039231",
#     "name": "Tachycardia"
#   },
#   "p": 0.999,
#   "mlp": 0.0
# }

# %%
r = predictor.find_new_relation(
    source_id='8670', # ACES_HUMAN
    target_id='309', # Bradycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN"
#   },
#   "target": {
#     "node_id": "309",
#     "namespace": "umls",
#     "identifier": "C0428977",
#     "name": "Bradycardia"
#   },
#   "p": 0.999,
#   "mlp": 0.0
# }

# %% [markdown]
# ## drug- side effect association

# %%
r = predictor.find_new_relation(
    source_id='3534',  # diazepam
    target_id='670',  # Libido decreased
)
print(json.dumps(r, indent=2))
#PMID: 29888057
# Out:
# {
#   "source": {
#     "node_id": "3534",
#     "namespace": "pubchem.compound",
#     "identifier": "3016",
#     "name": "Diazepam"
#   },
#   "target": {
#     "node_id": "670",
#     "namespace": "umls",
#     "identifier": "C0011124",
#     "name": "Libido decreased"
#   },
#   "p": 0.003,
#   "mlp": 2.499
# }

# %%
r = predictor.find_new_relation(
    source_id='1148',  # Cytarabine 
    target_id='1149',  # Anaemia megaloblastic
)
print(json.dumps(r, indent=2))
# PMID: 23157436
# Out:
# {
#   "source": {
#     "node_id": "1148",
#     "namespace": "pubchem.compound",
#     "identifier": "6175",
#     "name": "Cytidine"
#   },
#   "target": {
#     "node_id": "1149",
#     "namespace": "umls",
#     "identifier": "C0002888",
#     "name": "Anaemia megaloblastic"
#   },
#   "p": 0.085,
#   "mlp": 1.068
# }

# %% [markdown]
# ## drug-target association

# %%
r = predictor.find_new_relation(
    source_id='14672',  # Sertindole 
    target_id='9350',   # CHRM1 receptor
)
print(json.dumps(r, indent=2))
# PMID: 29942259
# Out:
# {
#   "source": {
#     "node_id": "14672",
#     "namespace": "pubchem.compound",
#     "identifier": "60149",
#     "name": "Sertindole"
#   },
#   "target": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN"
#   },
#   "p": 0.506,
#   "mlp": 0.296
# }

# %% [markdown]
# # Example of predicting relations using node2vec model and embeddings

# %%
def get_predictions_df(curie, results_type=None):
    results = predictor.find_new_relations(
        node_curie=curie,
        results_type=results_type,
        k=30,
    )
    results_df = pd.DataFrame(results['predictions'])
    results_df = results_df[['node_id', 'namespace', 'identifier', 'name', 'p', 'mlp', 'novel']]
    return results['query'], results_df

# %%
query, df = get_predictions_df('pubchem.compound:2159', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2173",
#     "namespace": "pubchem.compound",
#     "identifier": "2159",
#     "name": "Amisulpride"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                          name  \
# 0       88      umls   C0004936                               Mental disorder
# 1      103      umls   C0027769                                   Nervousness
# 2      209      umls   C0021053                        Immune system disorder
# 3      216      umls   C0032961                                     Pregnancy
# 4      224      umls   C0080274                             Urinary retention
# 5      271      umls   C0020651                       Orthostatic hypotension
# 6      331      umls   C0013144                                    Drowsiness
# 7      343      umls   C0040479                            Torsade de pointes
# 8      348      umls   C0085612                        Ventricular arrhythmia
# 9      366      umls   C0236071                              Throat tightness
# 10     395      umls   C0037036                       Salivary hypersecretion
# 11     427      umls   C0026961                                     Mydriasis
# 12     436      umls   C0033117                                      Priapism
# 13     549      umls   C0011206                                      Delirium
# 14     625      umls   C0018524                                 Hallucination
# 15     640      umls   C0033975                            Psychotic disorder
# 16     641      umls   C0151889                                 Hyperreflexia
# 17     652      umls   C0853193                            Bipolar I disorder
# 18     673      umls   C0011253                                      Delusion
# 19     680      umls   C0013384                                    Dyskinesia
# 20     687      umls   C0015371                       Extrapyramidal disorder
# 21     702      umls   C0018418                                 Gynaecomastia
# 22     717      umls   C0021141  Inappropriate antidiuretic hormone secretion
# 23     718      umls   C0021177                              Libido increased
# 24     728      umls   C0026837                               Muscle rigidity
# 25     777      umls   C0085623                                      Akinesia
# 26     797      umls   C0338831                                         Mania
# 27     808      umls   C0156404                        Menstruation irregular
# 28     852      umls   C0242422                                  Parkinsonism
# 29     862      umls   C0392156                                     Akathisia
#
#       p    mlp  novel
# 0   0.0  3.432  False
# 1   0.0  3.349  False
# 2   0.0  3.445  False
# 3   0.0  3.324  False
# 4   0.0  3.675   True
# 5   0.0  3.302  False
# 6   0.0  4.151   True
# 7   0.0  4.628  False
# 8   0.0  4.597  False
# 9   0.0  3.814   True
# 10  0.0  3.722  False
# 11  0.0  3.335   True
# 12  0.0  4.433   True
# 13  0.0  3.954   True
# 14  0.0  3.662  False
# 15  0.0  3.443   True
# 16  0.0  3.585   True
# 17  0.0  4.651   True
# 18  0.0  4.271  False
# 19  0.0  5.416  False
# 20  0.0  4.463  False
# 21  0.0  3.946  False
# 22  0.0  3.508   True
# 23  0.0  3.855   True
# 24  0.0  3.960  False
# 25  0.0  4.138   True
# 26  0.0  4.323   True
# 27  0.0  3.662   True
# 28  0.0  4.296   True
# 29  0.0  5.785  False

# %%
query, df = get_predictions_df('uniprot:P11229', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                           name      p    mlp  \
# 0     2181      umls   C0235293                 Taste peculiar  0.086  1.065
# 1      848      umls   C0241934                      Hypomania  0.151  0.820
# 2      935      umls   C2584688            Testicular swelling  0.152  0.817
# 3     2185      umls   C0424823               Parotid swelling  0.155  0.810
# 4     2200      umls   C0001416                       Adenitis  0.258  0.588
# 5     2183      umls   C0264886            Conduction disorder  0.329  0.483
# 6     2186      umls   C0341047      Parotid gland enlargement  0.365  0.438
# 7     2180      umls   C0152198         Accommodation disorder  0.444  0.353
# 8     1535      umls   C0338614              Psychotic episode  0.447  0.350
# 9     3568      umls   C0235238                    Cycloplegia  0.455  0.342
# 10    1951      umls   C0221490            Epigastric distress  0.472  0.326
# 11     427      umls   C0026961                      Mydriasis  0.480  0.318
# 12    4504      umls   C0006435                  Chemical burn  0.496  0.305
# 13    1036      umls   C0235660                  Galactorrhoea  0.508  0.294
# 14     606      umls   C0429098  Electrocardiogram QRS complex  0.564  0.249
# 15     652      umls   C0853193             Bipolar I disorder  0.609  0.215
# 16    7883      umls   C0011574        Involutional depression  0.609  0.215
# 17    4920      umls   C0747979      Increased prolactin level  0.613  0.213
# 18    3609      umls   C0578454                  Neck swelling  0.620  0.207
# 19     836      umls   C0235857          Lacrimation decreased  0.633  0.199
# 20    7708      umls   C0011573          Endogenous depression  0.646  0.190
# 21     605      umls   C0429097                    QRS complex  0.688  0.162
# 22    2178      umls   C0030446                Ileus paralytic  0.702  0.153
# 23    7822      umls   C0744896            Intractable hiccups  0.725  0.140
# 24    3571      umls   C0857257                Bloated feeling  0.731  0.136
# 25    7682      umls   C0282126            Neurotic depression  0.735  0.134
# 26     673      umls   C0011253                       Delusion  0.743  0.129
# 27    3721      umls   C0031133                  Vermiculation  0.759  0.120
# 28    3624      umls   C0242453                     Prostatism  0.766  0.116
# 29    6667      umls   C0343065             Urticaria physical  0.776  0.110
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
query, df = get_predictions_df('uniprot:P08588', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8733",
#     "namespace": "uniprot",
#     "identifier": "P08588",
#     "name": "ADRB1_HUMAN"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                               name      p  \
# 0     2471      umls   C0034735               Raynaud's phenomenon  0.077
# 1     1884      umls   C0701811             Short-term memory loss  0.097
# 2     1297      umls   C0018794                        Block heart  0.112
# 3     2181      umls   C0235293                     Taste peculiar  0.113
# 4     4348      umls   C0232201                       Sinus rhythm  0.120
# 5     8111      umls   C0154723                 Migraine with aura  0.210
# 6     2479      umls   C0235462                     Anginal attack  0.213
# 7     3619      umls   C0750197  Sustained ventricular tachycardia  0.214
# 8     1325      umls   C0857121                       Hypertensive  0.231
# 9     7709      umls   C0340288             Stable angina pectoris  0.250
# 10    3596      umls   C1698480   Supraventricular tachyarrhythmia  0.262
# 11    4464      umls   C0155709    Atrial fibrillation and flutter  0.267
# 12    1324      umls   C0234192                       Feeling cold  0.305
# 13    4641      umls   C0741983     Carotid sinus hypersensitivity  0.307
# 14    2183      umls   C0264886                Conduction disorder  0.345
# 15    6921      umls   C1321523                Wandering pacemaker  0.365
# 16    2113      umls   C0546959                 Atrial tachycardia  0.367
# 17    8162      umls   C0039236             Tachycardia paroxysmal  0.390
# 18    7769      umls   C0428776                      Cardiac index  0.423
# 19    2713      umls   C0001396              Adams-Stokes syndrome  0.430
# 20    1327      umls   C1735322              Injection site pallor  0.446
# 21    2266      umls   C0948786                          Blanching  0.484
# 22    1323      umls   C0812387                           Coldness  0.495
# 23    2731      umls   C0341742           Acute retention of urine  0.522
# 24    2290      umls   C1610080                      ANA increased  0.526
# 25     560      umls   C0600260       Obstructive airways disorder  0.530
# 26    3518      umls   C0376297                      Cardiac death  0.539
# 27    4504      umls   C0006435                      Chemical burn  0.545
# 28    6451      umls   C0401149               Constipation chronic  0.558
# 29    3600      umls   C0010073              Arteriospasm coronary  0.566
#
#       mlp  novel
# 0   1.114   True
# 1   1.014   True
# 2   0.949   True
# 3   0.947   True
# 4   0.920   True
# 5   0.678   True
# 6   0.673   True
# 7   0.669   True
# 8   0.637   True
# 9   0.602   True
# 10  0.582   True
# 11  0.574   True
# 12  0.515   True
# 13  0.513   True
# 14  0.462   True
# 15  0.437   True
# 16  0.436   True
# 17  0.408   True
# 18  0.374   True
# 19  0.367   True
# 20  0.351   True
# 21  0.315   True
# 22  0.305   True
# 23  0.283   True
# 24  0.279   True
# 25  0.276   True
# 26  0.269   True
# 27  0.264   True
# 28  0.253   True
# 29  0.247   True

# %%
query, df = get_predictions_df('uniprot:P22303', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0    17717  pubchem.compound     167159
# 1    13415  pubchem.compound    6604901
# 2    11601  pubchem.compound   12085802
# 3    16656  pubchem.compound   24871491
# 4    16874  pubchem.compound    2737071
# 5    11180  pubchem.compound     445999
# 6    13136  pubchem.compound       1174
# 7    16123  pubchem.compound   25138280
# 8    10419  pubchem.compound       2131
# 9    14335  pubchem.compound     446622
# 10   14063  pubchem.compound     448025
# 11   15108  pubchem.compound    6914624
# 12   12534  pubchem.compound      65077
# 13   16849  pubchem.compound   94286438
# 14   11785  pubchem.compound     446816
# 15   13993  pubchem.compound     637517
# 16    3615  pubchem.compound       3105
# 17   13437  pubchem.compound    9584748
# 18   12374  pubchem.compound     444378
# 19   17715  pubchem.compound   54710214
# 20   12192  pubchem.compound     447077
# 21   11972  pubchem.compound     448650
# 22   13153  pubchem.compound       6031
# 23   12362  pubchem.compound     445154
# 24   16393  pubchem.compound  131704307
# 25   12156  pubchem.compound     444729
# 26   14800  pubchem.compound    5276520
# 27    9810  pubchem.compound      31304
# 28   14450  pubchem.compound    5288476
# 29    5154  pubchem.compound       5755
#
#                                                  name      p    mlp  novel
# 0                             Ferrous glycine sulfate  0.004  2.391   True
# 1                    N-Ethyl-5'-Carboxamido Adenosine  0.006  2.204   True
# 2                                       Chlorophyll A  0.011  1.953   True
# 3   [4-({5-(AMINOCARBONYL)-4-[(3-METHYLPHENYL)AMIN...  0.012  1.932   True
# 4                       3-(4-nitrophenyl)-1H-pyrazole  0.015  1.823   True
# 5                     1,4-dithio-beta-D-glucopyranose  0.021  1.679   True
# 6                                              Uracil  0.024  1.617   True
# 7   4-[(2-{4-[(CYCLOPROPYLCARBAMOYL)AMINO]-1H-PYRA...  0.029  1.542   True
# 8                                          Ambenonium  0.029  1.544  False
# 9   2,6-Diamino-8-(1h-Imidazol-2-Ylsulfanylmethyl)...  0.030  1.519   True
# 10  {4-[(2s,4e)-2-(1,3-Benzothiazol-2-Yl)-2-(1h-1,...  0.033  1.481   True
# 11  N-[(4-HYDROXY-8-IODOISOQUINOLIN-3-YL)CARBONYL]...  0.033  1.483   True
# 12                                        Dansylamide  0.034  1.468   True
# 13  (5Z)-7-{(1R,4S,5R,6R)-6-[(1E)-1-Octen-1-yl]-2,...  0.035  1.456   True
# 14  1-(5-Tert-Butyl-2-Methyl-2h-Pyrazol-3-Yl)-3-(4...  0.035  1.451   True
# 15                                         Oleic Acid  0.037  1.427   True
# 16                                         Dipivefrin  0.038  1.417  False
# 17                         3-Hydroxyimino Quinic Acid  0.039  1.405   True
# 18                 7-Methyl-Guanosine-5'-Triphosphate  0.042  1.378   True
# 19                                  Ferrous ascorbate  0.042  1.378   True
# 20                                           PD173955  0.043  1.370   True
# 21       4-Hydroxy-1,2,5-Oxadiazole-3-Carboxylic Acid  0.044  1.353   True
# 22                             Uridine-5'-Diphosphate  0.044  1.353   True
# 23                                        Resveratrol  0.045  1.351   True
# 24  Methyl [(1E,5R)-5-{3-[(2E,4E)-2,5-dimethyl-2,4...  0.045  1.343   True
# 25          (10R)-10-Formyl-5,8,10-Trideazafolic Acid  0.046  1.334   True
# 26    (1-HYDROXYHEPTANE-1,1-DIYL)BIS(PHOSPHONIC ACID)  0.046  1.338   True
# 27                                         Picrotoxin  0.047  1.330   True
# 28  S-[(2E)-3,7-DIMETHYLOCTA-2,6-DIENYL] TRIHYDROG...  0.049  1.309   True
# 29                                       Prednisolone  0.049  1.306   True

# %%
query, df = get_predictions_df('uniprot:Q9UBN7', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "12164",
#     "namespace": "uniprot",
#     "identifier": "Q9UBN7",
#     "name": "HDAC6_HUMAN"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     4011  pubchem.compound   57515973
# 1     1148  pubchem.compound       6175
# 2     5451  pubchem.compound       5311
# 3     1796  pubchem.compound       1875
# 4     3562  pubchem.compound       3040
# 5     5722  pubchem.compound      31307
# 6     7180  pubchem.compound    6918638
# 7     5382  pubchem.compound      18283
# 8    14727  pubchem.compound    6918837
# 9     4064  pubchem.compound      60750
# 10    1921  pubchem.compound     457193
# 11    5154  pubchem.compound       5755
# 12    6983  pubchem.compound     667490
# 13    1973  pubchem.compound       2088
# 14    5735  pubchem.compound       5578
# 15    7487  pubchem.compound   70683024
# 16    4623  pubchem.compound     126941
# 17    4660  pubchem.compound       6741
# 18    2458  pubchem.compound      56069
# 19    4186  pubchem.compound       3657
# 20    5163  pubchem.compound       5865
# 21    2658  pubchem.compound    5288783
# 22    4637  pubchem.compound       4114
# 23    6695  pubchem.compound     148121
# 24    6701  pubchem.compound     148192
# 25    7055  pubchem.compound    5273759
# 26    2917  pubchem.compound       2708
# 27    3492  pubchem.compound       5743
# 28    5815  pubchem.compound       5746
# 29    6042  pubchem.compound      38904
#
#                                                  name      p    mlp  novel
# 0                                          Romidepsin  0.000  4.444  False
# 1                                            Cytidine  0.001  3.100   True
# 2                                          Vorinostat  0.001  3.099  False
# 3                                            AC1L1CFF  0.001  2.835   True
# 4   6-({[3-(2,6-dichlorophenyl)-5-methyl-1,2-oxazo...  0.001  3.220   True
# 5                                       Triamcinolone  0.001  2.880   True
# 6                                          Belinostat  0.001  3.282  False
# 7                                           Stavudine  0.002  2.660   True
# 8                                        Panobinostat  0.002  2.632  False
# 9                                         Gemcitabine  0.003  2.534   True
# 10                                       Dactinomycin  0.003  2.577   True
# 11                                       Prednisolone  0.003  2.584   True
# 12                                     Mercaptopurine  0.003  2.499   True
# 13                                    Alendronic acid  0.004  2.395   True
# 14                                       Trimethoprim  0.005  2.288   True
# 15                                    LIPEGFILGRASTIM  0.008  2.115   True
# 16                                       Methotrexate  0.009  2.033   True
# 17                                 Methylprednisolone  0.009  2.062   True
# 18                                   (R)-Bicalutamide  0.010  1.984   True
# 19                                        Hydroxyurea  0.010  2.015   True
# 20                                         Prednisone  0.010  2.014   True
# 21                                       Calcipotriol  0.012  1.933   True
# 22                                        Methoxsalen  0.012  1.931   True
# 23                                       Pralatrexate  0.012  1.909   True
# 24                                         Atazanavir  0.013  1.872   True
# 25                   Abacavir mixture with lamivudine  0.014  1.868   True
# 26                                       Chlorambucil  0.016  1.791   True
# 27                                      Dexamethasone  0.018  1.742   True
# 28                                          Mitomycin  0.019  1.733   True
# 29                                        Carboplatin  0.019  1.726   True

# %%
query, df = get_predictions_df("umls:C0030567", 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier                         name      p  \
# 0     2503  pubchem.compound      31101                Bromocriptine  0.000
# 1     5232  pubchem.compound       5002                   Quetiapine  0.000
# 2     6553  pubchem.compound     115237                 Paliperidone  0.000
# 3     2173  pubchem.compound       2159                  Amisulpride  0.000
# 4     6537  pubchem.compound     104778                      Duodopa  0.000
# 5     2750  pubchem.compound      34359                    Carbidopa  0.000
# 6     3272  pubchem.compound       2801                 Clomipramine  0.000
# 7     6316  pubchem.compound      60853                  138982-67-9  0.000
# 8     4915  pubchem.compound       4585                   Olanzapine  0.000
# 9     5388  pubchem.compound      26757                   Selegiline  0.000
# 10    5022  pubchem.compound      43815                   Paroxetine  0.000
# 11    5072  pubchem.compound      47811                    Pergolide  0.000
# 12    5119  pubchem.compound     119570                  Pramipexole  0.000
# 13    5293  pubchem.compound       5073                  Risperidone  0.000
# 14    5586  pubchem.compound       5452                 Thioridazine  0.000
# 15    5907  pubchem.compound      12453                     633-59-0  0.000
# 16    6243  pubchem.compound      60795                 Aripiprazole  0.000
# 17    6584  pubchem.compound    5289310  N-Propargyl-1(S)-Aminoindan  0.000
# 18    6628  pubchem.compound     123809                      Modopar  0.000
# 19    6755  pubchem.compound     156326              SCHEMBL12856886  0.000
# 20    6826  pubchem.compound     213046                   Lurasidone  0.000
# 21    7280  pubchem.compound   11505907                          NaN  0.000
# 22    4582  pubchem.compound       4054                    Memantine  0.001
# 23    4836  pubchem.compound       4449                   Nefazodone  0.001
# 24    3042  pubchem.compound     146570                 Escitalopram  0.001
# 25    3359  pubchem.compound       2818                    Clozapine  0.001
# 26    3968  pubchem.compound       3404                  Fluvoxamine  0.001
# 27    4490  pubchem.compound       3958                    Lorazepam  0.001
# 28    5589  pubchem.compound     941651                  Thiothixene  0.001
# 29    4499  pubchem.compound       3964                     Loxapine  0.001
#
#       mlp  novel
# 0   4.192  False
# 1   5.140   True
# 2   3.572  False
# 3   3.409   True
# 4   3.663  False
# 5   4.808  False
# 6   3.396  False
# 7   3.555   True
# 8   3.463  False
# 9   3.578  False
# 10  3.582  False
# 11  3.816  False
# 12  4.040  False
# 13  3.821  False
# 14  3.456   True
# 15  3.860   True
# 16  4.055  False
# 17  3.853  False
# 18  4.023  False
# 19  3.428   True
# 20  4.713  False
# 21  4.315  False
# 22  2.901  False
# 23  3.049   True
# 24  2.830   True
# 25  2.848   True
# 26  3.248   True
# 27  2.969   True
# 28  3.126   True
# 29  3.192   True

# %%
query, df = get_predictions_df('pubchem.compound:6234', 'phenotype')
print(json.dumps(query, indent=2))
df
#PMID: 29241812
# Out:
# {
#   "entity": {
#     "node_id": "635",
#     "namespace": "pubchem.compound",
#     "identifier": "6234",
#     "name": "Cycloserine"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                            name      p    mlp  \
# 0       54      umls   C0036572                      Convulsion  0.000  3.325
# 1      331      umls   C0013144                      Drowsiness  0.000  3.375
# 2      625      umls   C0018524                   Hallucination  0.001  2.953
# 3      640      umls   C0033975              Psychotic disorder  0.001  3.111
# 4     1467      umls   C0002878              Haemolytic anaemia  0.001  2.829
# 5      549      umls   C0011206                        Delirium  0.002  2.809
# 6      641      umls   C0151889                   Hyperreflexia  0.002  2.817
# 7      797      umls   C0338831                           Mania  0.002  2.664
# 8     1317      umls   C0022658                     Nephropathy  0.003  2.593
# 9     1395      umls   C0023052                Laryngeal oedema  0.003  2.461
# 10    1274      umls   C0239571                Foetor hepaticus  0.004  2.424
# 11    1135      umls   C0026848                        Myopathy  0.004  2.374
# 12    1272      umls   C0014457                    Eosinophilia  0.004  2.455
# 13     451      umls   C0043251                          Trauma  0.005  2.329
# 14     763      umls   C0038325        Stevens-Johnson syndrome  0.005  2.300
# 15     316      umls   C2830004                      Somnolence  0.006  2.219
# 16     552      umls   C0085628                          Stupor  0.006  2.248
# 17    1053      umls   C0302295                        Eruption  0.006  2.244
# 18     643      umls   C0234535               Clonic convulsion  0.006  2.214
# 19     673      umls   C0011253                        Delusion  0.006  2.230
# 20    1458      umls   C0027707          Nephritis interstitial  0.006  2.229
# 21    1509      umls   C0919715             Lupus-like syndrome  0.006  2.188
# 22    2389      umls   C0030807                       Pemphigus  0.006  2.202
# 23    2072      umls   C0027849  Neuroleptic malignant syndrome  0.006  2.209
# 24    2368      umls   C0020701                        Hysteria  0.006  2.189
# 25     636      umls   C0001807                      Aggression  0.008  2.104
# 26     565      umls   C0001824                 Agranulocytosis  0.010  2.006
# 27     734      umls   C0028084                       Nightmare  0.010  1.989
# 28     831      umls   C0235146                   Euphoric mood  0.010  2.000
# 29     701      umls   C0017979                      Glycosuria  0.011  1.963
#
#     novel
# 0   False
# 1   False
# 2    True
# 3   False
# 4    True
# 5    True
# 6   False
# 7    True
# 8   False
# 9    True
# 10  False
# 11   True
# 12   True
# 13   True
# 14   True
# 15  False
# 16   True
# 17   True
# 18  False
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25  False
# 26   True
# 27   True
# 28   True
# 29   True

# %%
r = predictor.find_new_relation(
    source_id='2071', #Amantadine
    target_id='2248', #Parkinson's disease
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "2071",
#     "namespace": "pubchem.compound",
#     "identifier": "2130",
#     "name": "Amantadine"
#   },
#   "target": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease"
#   },
#   "p": 0.002,
#   "mlp": 2.701
# }

# %%
r = predictor.find_new_relation(
    source_id='5346', #Ropinirole
    target_id='1348', #Restless legs syndrome
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole"
#   },
#   "target": {
#     "node_id": "1348",
#     "namespace": "umls",
#     "identifier": "C0035258",
#     "name": "Restless legs syndrome"
#   },
#   "p": 0.009,
#   "mlp": 2.055
# }

# %%
r = predictor.find_new_relation(
    source_id='3627', #Disulfiram
    target_id='2318', #Malignant melanoma
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "3627",
#     "namespace": "pubchem.compound",
#     "identifier": "3117",
#     "name": "Disulfiram"
#   },
#   "target": {
#     "node_id": "2318",
#     "namespace": "umls",
#     "identifier": "C0025202",
#     "name": "Malignant melanoma"
#   },
#   "p": 0.928,
#   "mlp": 0.032
# }

# %%
r = predictor.find_new_relation(
    source_id='17528', #Brigatinib
    target_id='5148', #Colorectal cancer
)
print(json.dumps(r, indent=2))
#PMID: 31410188
# Out:
# {
#   "source": {
#     "node_id": "17528",
#     "namespace": "uniprot",
#     "identifier": "Q99640",
#     "name": "PMYT1_HUMAN"
#   },
#   "target": {
#     "node_id": "5148",
#     "namespace": "umls",
#     "identifier": "C1527249",
#     "name": "Colorectal cancer"
#   },
#   "p": 1.0,
#   "mlp": 0.0
# }

# %%
r = predictor.find_new_relation(
    source_id='6995', #dasatinib
    target_id='1179', #Diffuse large B-cell lymphoma
)
print(json.dumps(r, indent=2))
#PMID: 31383760
# Out:
# {
#   "source": {
#     "node_id": "6995",
#     "namespace": "pubchem.compound",
#     "identifier": "3062316",
#     "name": "Dasatinib"
#   },
#   "target": {
#     "node_id": "1179",
#     "namespace": "umls",
#     "identifier": "C0079744",
#     "name": "Diffuse large B-cell lymphoma"
#   },
#   "p": 0.973,
#   "mlp": 0.012
# }

# %%
r = predictor.find_new_relation(
    source_id='5265', #ribavirin
    target_id='947', #Candida infection
)
print(json.dumps(r, indent=2))
#PMID: 31307986
# Out:
# {
#   "source": {
#     "node_id": "5265",
#     "namespace": "pubchem.compound",
#     "identifier": "37542",
#     "name": "Ribavirin"
#   },
#   "target": {
#     "node_id": "947",
#     "namespace": "umls",
#     "identifier": "C0006840",
#     "name": "Candida infection"
#   },
#   "p": 0.103,
#   "mlp": 0.989
# }
