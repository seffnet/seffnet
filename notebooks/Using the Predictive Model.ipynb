# %% [markdown]
# # Using the Prediction Model
#
# ## Environment

# %%
import getpass
import json
import os
import sys
import time

import pandas as pd

from seffnet.constants import (
    DEFAULT_EMBEDDINGS_PATH, DEFAULT_GRAPH_PATH,
    DEFAULT_MAPPING_PATH, DEFAULT_MODEL_PATH,
)

# %%
print(sys.version)
# Out:
# 3.7.2 (tags/v3.7.2:9a3ffc0492, Dec 23 2018, 23:09:28) [MSC v.1916 64 bit (AMD64)]

# %%
print(time.asctime())
# Out:
# Fri Sep 13 13:17:54 2019

# %%
print(getpass.getuser())
# Out:
# RanaAldisi

# %% [markdown]
# # Loading the Data

# %%
from seffnet.default_predictor import predictor

# %%
print(f"""Loaded default predictor using paths:

embeddings: {DEFAULT_EMBEDDINGS_PATH}
graph:      {DEFAULT_GRAPH_PATH}
model:      {DEFAULT_MODEL_PATH}
mapping:    {DEFAULT_MAPPING_PATH}
""")
# Out:
# Loaded default predictor using paths:
#
# embeddings: c:\users\rana aldisi\documents\github\se_kge\resources\predictive_model\1209_node2vec_emb.embeddings
# graph:      c:\users\rana aldisi\documents\github\se_kge\resources\basic_graphs\fullgraph_with_chemsim.edgelist
# model:      c:\users\rana aldisi\documents\github\se_kge\resources\predictive_model\1209_node2vec_model.pkl
# mapping:    c:\users\rana aldisi\documents\github\se_kge\resources\mapping\fullgraph_nodes_mapping.tsv

# %% [markdown]
# # Examples of different kinds of predictions with literature evidence

# %% [markdown]
# ## side effect - target association

# %%
r = predictor.find_new_relation(
    source_name='EGFR_HUMAN',
    target_name='Papulopustular rash',
)
print(json.dumps(r, indent=2))
#PMID: 18165622
# Out:
# {
#   "source": {
#     "node_id": "9587",
#     "namespace": "uniprot",
#     "identifier": "P00533",
#     "name": "EGFR_HUMAN"
#   },
#   "target": {
#     "node_id": "6791",
#     "namespace": "umls",
#     "identifier": "C2609319",
#     "name": "Papulopustular rash"
#   },
#   "p": 0.853,
#   "mlp": 0.069
# }

# %%
r = predictor.find_new_relation(
    source_id='9451', # Histamine receptor H1
    target_id='331', # Drowsiness
)
print(json.dumps(r, indent=2))
#PMID: 26626077
# Out:
# {
#   "source": {
#     "node_id": "9451",
#     "namespace": "uniprot",
#     "identifier": "P35367",
#     "name": "HRH1_HUMAN"
#   },
#   "target": {
#     "node_id": "331",
#     "namespace": "umls",
#     "identifier": "C0013144",
#     "name": "Drowsiness"
#   },
#   "p": 0.438,
#   "mlp": 0.358
# }

# %%
r = predictor.find_new_relation(
    source_id='9325', # SC6A2
    target_id='56', # Tachycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "9325",
#     "namespace": "uniprot",
#     "identifier": "P23975",
#     "name": "SC6A2_HUMAN"
#   },
#   "target": {
#     "node_id": "56",
#     "namespace": "umls",
#     "identifier": "C0039231",
#     "name": "Tachycardia"
#   },
#   "p": 0.328,
#   "mlp": 0.485
# }

# %%
r = predictor.find_new_relation(
    source_id='8670', # ACES_HUMAN
    target_id='309', # Bradycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN"
#   },
#   "target": {
#     "node_id": "309",
#     "namespace": "umls",
#     "identifier": "C0428977",
#     "name": "Bradycardia"
#   },
#   "p": 0.937,
#   "mlp": 0.028
# }

# %% [markdown]
# ## drug- side effect association

# %%
r = predictor.find_new_relation(
    source_id='3534',  # diazepam
    target_id='670',  # Libido decreased
)
print(json.dumps(r, indent=2))
#PMID: 29888057
# Out:
# {
#   "source": {
#     "node_id": "3534",
#     "namespace": "pubchem.compound",
#     "identifier": "3016",
#     "name": "Diazepam"
#   },
#   "target": {
#     "node_id": "670",
#     "namespace": "umls",
#     "identifier": "C0011124",
#     "name": "Libido decreased"
#   },
#   "p": 0.008,
#   "mlp": 2.076
# }

# %%
r = predictor.find_new_relation(
    source_id='1148',  # Cytarabine 
    target_id='1149',  # Anaemia megaloblastic
)
print(json.dumps(r, indent=2))
# PMID: 23157436
# Out:
# {
#   "source": {
#     "node_id": "1148",
#     "namespace": "pubchem.compound",
#     "identifier": "6175",
#     "name": "Cytidine"
#   },
#   "target": {
#     "node_id": "1149",
#     "namespace": "umls",
#     "identifier": "C0002888",
#     "name": "Anaemia megaloblastic"
#   },
#   "p": 0.198,
#   "mlp": 0.703
# }

# %% [markdown]
# ## drug-target association

# %%
r = predictor.find_new_relation(
    source_id='14672',  # Sertindole 
    target_id='9350',   # CHRM1 receptor
)
print(json.dumps(r, indent=2))
# PMID: 29942259
# Out:
# {
#   "source": {
#     "node_id": "14672",
#     "namespace": "pubchem.compound",
#     "identifier": "60149",
#     "name": "Sertindole"
#   },
#   "target": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN"
#   },
#   "p": 0.051,
#   "mlp": 1.291
# }

# %% [markdown]
# # Example of predicting relations using node2vec model and embeddings

# %%
def get_predictions_df(curie, results_type=None):
    results = predictor.find_new_relations(
        node_curie=curie,
        results_type=results_type,
        k=30,
    )
    results_df = pd.DataFrame(results['predictions'])
    results_df = results_df[['node_id', 'namespace', 'identifier', 'name', 'p', 'mlp', 'novel']]
    return results['query'], results_df

# %%
query, df = get_predictions_df('pubchem.compound:2159', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2173",
#     "namespace": "pubchem.compound",
#     "identifier": "2159",
#     "name": "Amisulpride"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                               name      p  \
# 0       27      umls   C0011603                         Dermatitis  0.001
# 1      831      umls   C0235146                      Euphoric mood  0.001
# 2      331      umls   C0013144                         Drowsiness  0.002
# 3      427      umls   C0026961                          Mydriasis  0.002
# 4      818      umls   C0233477                          Dysphoria  0.002
# 5      852      umls   C0242422                       Parkinsonism  0.002
# 6      734      umls   C0028084                          Nightmare  0.002
# 7      797      umls   C0338831                              Mania  0.002
# 8       26      umls   C0015230                               Rash  0.003
# 9      182      umls   C0009676                  Confusional state  0.003
# 10     170      umls   C1443060                   Feeling abnormal  0.003
# 11     641      umls   C0151889                      Hyperreflexia  0.003
# 12    1967      umls   C0855329           Electrocardiogram change  0.003
# 13     858      umls   C0277925                Peripheral coldness  0.004
# 14    2140      umls   C0151878     Electrocardiogram QT prolonged  0.004
# 15     670      umls   C0011124                   Libido decreased  0.004
# 16    1500      umls   C0233571                         Excitement  0.004
# 17     140      umls   C0349506                   Photosensitivity  0.005
# 18     436      umls   C0033117                           Priapism  0.005
# 19     463      umls   C0855775  Pulmonary function test decreased  0.005
# 20    1539      umls   C0006384                Bundle branch block  0.005
# 21     718      umls   C0021177                   Libido increased  0.005
# 22     671      umls   C0855242      Disturbance in sexual arousal  0.005
# 23    1710      umls   C0575090                   Balance disorder  0.005
# 24     977      umls   C0021167                       Incontinence  0.005
# 25      29      umls   C0015967         Body temperature increased  0.006
# 26     826      umls   C0233794                  Memory impairment  0.006
# 27    1396      umls   C0023066                       Laryngospasm  0.006
# 28     308      umls   C0424295                       Hyperkinesia  0.006
# 29    1993      umls   C0026205                             Miosis  0.006
#
#       mlp  novel
# 0   3.020   True
# 1   2.852   True
# 2   2.707   True
# 3   2.660   True
# 4   2.759   True
# 5   2.756   True
# 6   2.714   True
# 7   2.651   True
# 8   2.554   True
# 9   2.575   True
# 10  2.467   True
# 11  2.530   True
# 12  2.529   True
# 13  2.354   True
# 14  2.430   True
# 15  2.433   True
# 16  2.430   True
# 17  2.343   True
# 18  2.332   True
# 19  2.276   True
# 20  2.299   True
# 21  2.342   True
# 22  2.285   True
# 23  2.306   True
# 24  2.319   True
# 25  2.209   True
# 26  2.229   True
# 27  2.208   True
# 28  2.245   True
# 29  2.242   True

# %%
query, df = get_predictions_df('pubchem.compound:4585', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "4915",
#     "namespace": "pubchem.compound",
#     "identifier": "4585",
#     "name": "Olanzapine"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                          name  \
# 0     1539      umls   C0006384                           Bundle branch block
# 1     1710      umls   C0575090                              Balance disorder
# 2     1210      umls   C0878544                                Cardiomyopathy
# 3      826      umls   C0233794                             Memory impairment
# 4     1714      umls   C0004239                                Atrial flutter
# 5      795      umls   C0160390                                  Liver injury
# 6     1289      umls   C0020676                                Hypothyroidism
# 7      403      umls   C0002884                           Hypochromic anaemia
# 8     1599      umls   C0034069                            Pulmonary fibrosis
# 9      818      umls   C0233477                                     Dysphoria
# 10     641      umls   C0151889                                 Hyperreflexia
# 11    2157      umls   C0427086                         Movements involuntary
# 12     656      umls   C0006325                                       Bruxism
# 13     830      umls   C0235086               Muscle contractions involuntary
# 14     784      umls   C0152128                      Drug withdrawal syndrome
# 15    1660      umls   C0151888                                  Hyporeflexia
# 16    2299      umls   C0039520                                 Tenosynovitis
# 17      87      umls   C0003537                                       Aphasia
# 18     901      umls   C0558489                                    Renal pain
# 19     455      umls   C0151734                   Injection site inflammation
# 20    1247      umls   C0151826                             Retrosternal pain
# 21    1578      umls   C0235639                             Urine abnormality
# 22     717      umls   C0021141  Inappropriate antidiuretic hormone secretion
# 23    1479      umls   C0917798                            Cerebral ischaemia
# 24    2178      umls   C0030446                               Ileus paralytic
# 25    2008      umls   C0024282                                 Lymphocytosis
# 26      64      umls   C0234930                           Skin odour abnormal
# 27     105      umls   C0031256                                     Petechiae
# 28     122      umls   C0151717                              Skin hypertrophy
# 29    1156      umls   C0018991                                    Hemiplegia
#
#         p    mlp  novel
# 0   0.000  3.475   True
# 1   0.000  3.539   True
# 2   0.001  2.918   True
# 3   0.001  2.870   True
# 4   0.001  3.297   True
# 5   0.001  3.175   True
# 6   0.001  2.911   True
# 7   0.001  3.059   True
# 8   0.001  2.901   True
# 9   0.001  3.066   True
# 10  0.001  3.003   True
# 11  0.001  2.874   True
# 12  0.001  3.018   True
# 13  0.001  3.120   True
# 14  0.001  3.232   True
# 15  0.001  3.099   True
# 16  0.001  3.092   True
# 17  0.002  2.784   True
# 18  0.002  2.742   True
# 19  0.002  2.763   True
# 20  0.002  2.684   True
# 21  0.002  2.618   True
# 22  0.002  2.658   True
# 23  0.002  2.725   True
# 24  0.002  2.699   True
# 25  0.002  2.803   True
# 26  0.003  2.482   True
# 27  0.003  2.460   True
# 28  0.003  2.463   True
# 29  0.003  2.504   True

# %%
query, df = get_predictions_df('uniprot:P08172', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "9429",
#     "namespace": "uniprot",
#     "identifier": "P08172",
#     "name": "ACM2_HUMAN"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                               name      p  \
# 0      680      umls   C0013384                         Dyskinesia  0.009
# 1      687      umls   C0015371            Extrapyramidal disorder  0.013
# 2      728      umls   C0026837                    Muscle rigidity  0.015
# 3     2146      umls   C0234133            Extrapyramidal symptoms  0.022
# 4      427      umls   C0026961                          Mydriasis  0.023
# 5      331      umls   C0013144                         Drowsiness  0.025
# 6      292      umls   C0085631                          Agitation  0.025
# 7      908      umls   C0686347                 Tardive dyskinesia  0.038
# 8      852      umls   C0242422                       Parkinsonism  0.044
# 9      462      umls   C0235063             Respiratory depression  0.053
# 10     463      umls   C0855775  Pulmonary function test decreased  0.055
# 11    1500      umls   C0233571                         Excitement  0.060
# 12    2178      umls   C0030446                    Ileus paralytic  0.062
# 13     734      umls   C0028084                          Nightmare  0.068
# 14     702      umls   C0018418                      Gynaecomastia  0.090
# 15     783      umls   C0087169                 Withdrawal symptom  0.094
# 16     348      umls   C0085612             Ventricular arrhythmia  0.095
# 17    2072      umls   C0027849     Neuroleptic malignant syndrome  0.097
# 18     308      umls   C0424295                       Hyperkinesia  0.098
# 19     640      umls   C0033975                 Psychotic disorder  0.120
# 20    1804      umls   C0036341                      Schizophrenia  0.123
# 21     601      umls   C0234518                     Slurred speech  0.132
# 22    1993      umls   C0026205                             Miosis  0.142
# 23     238      umls   C0344232                     Vision blurred  0.143
# 24       2      umls   C0000729                   Abdominal cramps  0.147
# 25     684      umls   C0014394                           Enuresis  0.157
# 26     436      umls   C0033117                           Priapism  0.172
# 27    2074      umls   C0085637                  Oculogyric crisis  0.182
# 28      26      umls   C0015230                               Rash  0.184
# 29    2944      umls   C0700075                 Motor restlessness  0.191
#
#       mlp  novel
# 0   2.070   True
# 1   1.889   True
# 2   1.811   True
# 3   1.649   True
# 4   1.639   True
# 5   1.605   True
# 6   1.597   True
# 7   1.419   True
# 8   1.356   True
# 9   1.273   True
# 10  1.260   True
# 11  1.225   True
# 12  1.210   True
# 13  1.170   True
# 14  1.046   True
# 15  1.029   True
# 16  1.022   True
# 17  1.014   True
# 18  1.008   True
# 19  0.920   True
# 20  0.909   True
# 21  0.879   True
# 22  0.847   True
# 23  0.844   True
# 24  0.831   True
# 25  0.803   True
# 26  0.765   True
# 27  0.740   True
# 28  0.735   True
# 29  0.719   True

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lllllrrl}
# \toprule
# {} & node\_id & namespace & identifier &                               name &      p &    mlp &  novel \\
# \midrule
# 0  &     680 &      umls &   C0013384 &                         Dyskinesia &  0.009 &  2.070 &   True \\
# 1  &     687 &      umls &   C0015371 &            Extrapyramidal disorder &  0.013 &  1.889 &   True \\
# 2  &     728 &      umls &   C0026837 &                    Muscle rigidity &  0.015 &  1.811 &   True \\
# 3  &    2146 &      umls &   C0234133 &            Extrapyramidal symptoms &  0.022 &  1.649 &   True \\
# 4  &     427 &      umls &   C0026961 &                          Mydriasis &  0.023 &  1.639 &   True \\
# 5  &     331 &      umls &   C0013144 &                         Drowsiness &  0.025 &  1.605 &   True \\
# 6  &     292 &      umls &   C0085631 &                          Agitation &  0.025 &  1.597 &   True \\
# 7  &     908 &      umls &   C0686347 &                 Tardive dyskinesia &  0.038 &  1.419 &   True \\
# 8  &     852 &      umls &   C0242422 &                       Parkinsonism &  0.044 &  1.356 &   True \\
# 9  &     462 &      umls &   C0235063 &             Respiratory depression &  0.053 &  1.273 &   True \\
# 10 &     463 &      umls &   C0855775 &  Pulmonary function test decreased &  0.055 &  1.260 &   True \\
# 11 &    1500 &      umls &   C0233571 &                         Excitement &  0.060 &  1.225 &   True \\
# 12 &    2178 &      umls &   C0030446 &                    Ileus paralytic &  0.062 &  1.210 &   True \\
# 13 &     734 &      umls &   C0028084 &                          Nightmare &  0.068 &  1.170 &   True \\
# 14 &     702 &      umls &   C0018418 &                      Gynaecomastia &  0.090 &  1.046 &   True \\
# 15 &     783 &      umls &   C0087169 &                 Withdrawal symptom &  0.094 &  1.029 &   True \\
# 16 &     348 &      umls &   C0085612 &             Ventricular arrhythmia &  0.095 &  1.022 &   True \\
# 17 &    2072 &      umls &   C0027849 &     Neuroleptic malignant syndrome &  0.097 &  1.014 &   True \\
# 18 &     308 &      umls &   C0424295 &                       Hyperkinesia &  0.098 &  1.008 &   True \\
# 19 &     640 &      umls &   C0033975 &                 Psychotic disorder &  0.120 &  0.920 &   True \\
# 20 &    1804 &      umls &   C0036341 &                      Schizophrenia &  0.123 &  0.909 &   True \\
# 21 &     601 &      umls &   C0234518 &                     Slurred speech &  0.132 &  0.879 &   True \\
# 22 &    1993 &      umls &   C0026205 &                             Miosis &  0.142 &  0.847 &   True \\
# 23 &     238 &      umls &   C0344232 &                     Vision blurred &  0.143 &  0.844 &   True \\
# 24 &       2 &      umls &   C0000729 &                   Abdominal cramps &  0.147 &  0.831 &   True \\
# 25 &     684 &      umls &   C0014394 &                           Enuresis &  0.157 &  0.803 &   True \\
# 26 &     436 &      umls &   C0033117 &                           Priapism &  0.172 &  0.765 &   True \\
# 27 &    2074 &      umls &   C0085637 &                  Oculogyric crisis &  0.182 &  0.740 &   True \\
# 28 &      26 &      umls &   C0015230 &                               Rash &  0.184 &  0.735 &   True \\
# 29 &    2944 &      umls &   C0700075 &                 Motor restlessness &  0.191 &  0.719 &   True \\
# \bottomrule
# \end{tabular}

# %%
query, df = get_predictions_df('uniprot:P08588', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8733",
#     "namespace": "uniprot",
#     "identifier": "P08588",
#     "name": "ADRB1_HUMAN"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                               name      p  \
# 0      218      umls   C0040822                             Tremor  0.001
# 1      331      umls   C0013144                         Drowsiness  0.003
# 2      851      umls   C0242350               Erectile dysfunction  0.006
# 3     1500      umls   C0233571                         Excitement  0.006
# 4      734      umls   C0028084                          Nightmare  0.009
# 5      164      umls   C0015672                            Fatigue  0.010
# 6      181      umls   C0036974                              Shock  0.010
# 7     1324      umls   C0234192                       Feeling cold  0.012
# 8      316      umls   C2830004                         Somnolence  0.014
# 9      427      umls   C0026961                          Mydriasis  0.014
# 10     345      umls   C0042514            Ventricular tachycardia  0.014
# 11      56      umls   C0039231                        Tachycardia  0.017
# 12     680      umls   C0013384                         Dyskinesia  0.017
# 13     728      umls   C0026837                    Muscle rigidity  0.019
# 14     238      umls   C0344232                     Vision blurred  0.020
# 15    1325      umls   C0857121                       Hypertensive  0.021
# 16    1396      umls   C0023066                       Laryngospasm  0.021
# 17    1993      umls   C0026205                             Miosis  0.021
# 18     348      umls   C0085612             Ventricular arrhythmia  0.021
# 19     182      umls   C0009676                  Confusional state  0.022
# 20     170      umls   C1443060                   Feeling abnormal  0.024
# 21     463      umls   C0855775  Pulmonary function test decreased  0.024
# 22     862      umls   C0392156                          Akathisia  0.024
# 23     330      umls   C0004245             Atrioventricular block  0.027
# 24     642      umls   C0233407                     Disorientation  0.027
# 25      22      umls   C0012833                          Dizziness  0.028
# 26     359      umls   C0220870                    Lightheadedness  0.028
# 27    1420      umls   C0038587                Withdrawal syndrome  0.032
# 28     831      umls   C0235146                      Euphoric mood  0.038
# 29     625      umls   C0018524                      Hallucination  0.042
#
#       mlp  novel
# 0   3.275   True
# 1   2.582   True
# 2   2.225   True
# 3   2.195   True
# 4   2.046   True
# 5   2.010   True
# 6   1.981   True
# 7   1.933   True
# 8   1.858   True
# 9   1.853   True
# 10  1.847   True
# 11  1.781   True
# 12  1.776   True
# 13  1.725   True
# 14  1.708   True
# 15  1.676   True
# 16  1.678   True
# 17  1.676   True
# 18  1.683   True
# 19  1.655   True
# 20  1.615   True
# 21  1.616   True
# 22  1.614   True
# 23  1.569   True
# 24  1.566   True
# 25  1.554   True
# 26  1.547   True
# 27  1.498   True
# 28  1.425   True
# 29  1.381   True

# %%
query, df = get_predictions_df('uniprot:P22303', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier  \
# 0       45      umls   C0027497
# 1      109      umls   C0037274
# 2       26      umls   C0015230
# 3       11      umls   C0004093
# 4      209      umls   C0021053
# 5      129      umls   C0178298
# 6       18      umls   C0009806
# 7        2      umls   C0000729
# 8      260      umls   C0009782
# 9       66      umls   C0151735
# 10      28      umls   C0015397
# 11     164      umls   C0015672
# 12      31      umls   C0017178
# 13     168      umls   C0043144
# 14      88      umls   C0004936
# 15     541      umls   C0162429
# 16     449      umls   C0041969
# 17      27      umls   C0011603
# 18     152      umls   C1384353
# 19     655      umls   C0006145
# 20     151      umls   C0851341
# 21     265      umls   C0016204
# 22      85      umls   C0151828
# 23       3      umls   C0000737
# 24      51      umls   C0033774
# 25      22      umls   C0012833
# 26     170      umls   C1443060
# 27     331      umls   C0013144
# 28     205      umls   C0016382
# 29     977      umls   C0021167
#
#                                                  name      p    mlp  novel
# 0                                              Nausea  0.002  2.793   True
# 1                                       Skin disorder  0.024  1.625   True
# 2                                                Rash  0.026  1.592   True
# 3                                            Asthenia  0.029  1.539   True
# 4                              Immune system disorder  0.038  1.424   True
# 5   Unspecified disorder of skin and subcutaneous ...  0.054  1.264   True
# 6                                        Constipation  0.097  1.012   True
# 7                                    Abdominal cramps  0.179  0.747   True
# 8                          Connective tissue disorder  0.225  0.648   True
# 9                             Injection site reaction  0.250  0.603   True
# 10                                       Eye disorder  0.263  0.579   True
# 11                                            Fatigue  0.304  0.517   True
# 12                          Gastrointestinal disorder  0.356  0.449   True
# 13                                           Wheezing  0.377  0.423   True
# 14                                    Mental disorder  0.417  0.380   True
# 15                                       Malnutrition  0.480  0.319   True
# 16                                  Urethral disorder  0.490  0.310   True
# 17                                         Dermatitis  0.552  0.258   True
# 18                                        Infestation  0.571  0.244   True
# 19                                    Breast disorder  0.623  0.206   True
# 20                                    Infestation NOS  0.649  0.188   True
# 21                                         Flatulence  0.650  0.187   True
# 22                                Injection site pain  0.663  0.178   True
# 23                                     Abdominal pain  0.675  0.170   True
# 24                                           Pruritus  0.677  0.170   True
# 25                                          Dizziness  0.679  0.168   True
# 26                                   Feeling abnormal  0.686  0.164   True
# 27                                         Drowsiness  0.688  0.162   True
# 28                                           Flushing  0.711  0.148   True
# 29                                       Incontinence  0.719  0.143   True

# %%
query, df = get_predictions_df('uniprot:Q9UBN7', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "12164",
#     "namespace": "uniprot",
#     "identifier": "Q9UBN7",
#     "name": "HDAC6_HUMAN"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0     3187  pubchem.compound    1548953
# 1     3042  pubchem.compound     146570
# 2     1616  pubchem.compound       1690
# 3     5727  pubchem.compound       5565
# 4     6633  pubchem.compound    5486971
# 5     3799  pubchem.compound       3333
# 6     3562  pubchem.compound       3040
# 7     3857  pubchem.compound       3355
# 8     5382  pubchem.compound      18283
# 9     4507  pubchem.compound       4030
# 10    5735  pubchem.compound       5578
# 11    3782  pubchem.compound       3325
# 12    2636  pubchem.compound      54746
# 13    1536  pubchem.compound       1301
# 14    5646  pubchem.compound      33741
# 15    3396  pubchem.compound       2907
# 16    1751  pubchem.compound       1798
# 17    4064  pubchem.compound      60750
# 18    5961  pubchem.compound      23925
# 19    6607  pubchem.compound     123619
# 20     328  pubchem.compound     447916
# 21    3995  pubchem.compound     446987
# 22    1973  pubchem.compound       2088
# 23    7048  pubchem.compound    5281081
# 24   13464  pubchem.compound       8642
# 25    7094  pubchem.compound    5493381
# 26    6822  pubchem.compound     213039
# 27    4186  pubchem.compound       3657
# 28    2458  pubchem.compound      56069
# 29    4855  pubchem.compound       4493
#
#                                                  name      p    mlp  novel
# 0                                        Enclomiphene  0.039  1.405   True
# 1                                        Escitalopram  0.439  0.358   True
# 2                                            AC1L1C0O  0.463  0.334   True
# 3                                Triethylenetetramine  0.551  0.259   True
# 4                                          Pregabalin  0.552  0.258   True
# 5                                          Felodipine  0.579  0.238   True
# 6   6-({[3-(2,6-dichlorophenyl)-5-methyl-1,2-oxazo...  0.624  0.205   True
# 7                                            AC1L1FQW  0.630  0.200   True
# 8                                           Stavudine  0.633  0.198   True
# 9                                         Mebendazole  0.644  0.191   True
# 10                                       Trimethoprim  0.680  0.168   True
# 11                                         Famotidine  0.685  0.164   True
# 12                                        Cabergoline  0.693  0.159   True
# 13      sodium 2-(6-methoxynaphthalen-2-yl)propanoate  0.695  0.158   True
# 14                                           Tramadol  0.696  0.157   True
# 15                                   Cyclophosphamide  0.717  0.145   True
# 16                                                MZM  0.717  0.144   True
# 17                                        Gemcitabine  0.718  0.144   True
# 18                                               Iron  0.719  0.144   True
# 19                                         Etoricoxib  0.721  0.142   True
# 20                     9-Beta-D-Xylofuranosyl-Adenine  0.724  0.140   True
# 21                                         Fosfomycin  0.725  0.139   True
# 22                                    Alendronic acid  0.726  0.139   True
# 23                                         Entacapone  0.728  0.138   True
# 24          5-Fluoro-2'-Deoxyuridine-5'-Monophosphate  0.737  0.133   True
# 25                                        Deferasirox  0.746  0.127   True
# 26                                          Darunavir  0.751  0.125   True
# 27                                        Hydroxyurea  0.752  0.124   True
# 28                                   (R)-Bicalutamide  0.756  0.122   True
# 29                                         Nilutamide  0.757  0.121   True

# %%
query, df = get_predictions_df("umls:C0030567", 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier                    name      p    mlp  \
# 0     3042  pubchem.compound     146570            Escitalopram  0.000  3.315
# 1     5232  pubchem.compound       5002              Quetiapine  0.001  2.883
# 2     6633  pubchem.compound    5486971              Pregabalin  0.001  3.111
# 3     5391  pubchem.compound      68617              Sertraline  0.002  2.763
# 4     5799  pubchem.compound       5719                Zaleplon  0.002  2.807
# 5     6316  pubchem.compound      60853             138982-67-9  0.002  2.613
# 6     3811  pubchem.compound       3345                Fentanyl  0.002  2.630
# 7     5401  pubchem.compound       5210             Sibutramine  0.002  2.613
# 8     2365  pubchem.compound      44602              Arbaclofen  0.003  2.554
# 9     4647  pubchem.compound     154101      Dexmethylphenidate  0.003  2.475
# 10    5618  pubchem.compound    5284627              Topiramate  0.003  2.483
# 11    5703  pubchem.compound       5533               Trazodone  0.003  2.593
# 12    5907  pubchem.compound      12453                633-59-0  0.003  2.593
# 13    6390  pubchem.compound     127151              Reboxetine  0.003  2.554
# 14    4807  pubchem.compound    5360515              Naltrexone  0.004  2.449
# 15    3968  pubchem.compound       3404             Fluvoxamine  0.004  2.392
# 16    5590  pubchem.compound      60648               Tiagabine  0.004  2.437
# 17    6030  pubchem.compound      34312           Oxcarbazepine  0.004  2.358
# 18    5931  pubchem.compound      16362                Pimozide  0.004  2.391
# 19    4506  pubchem.compound       4011             Maprotiline  0.005  2.265
# 20    6600  pubchem.compound     123606             Almotriptan  0.005  2.298
# 21    2044  pubchem.compound       2118              Alprazolam  0.005  2.314
# 22    4030  pubchem.compound       3446              Gabapentin  0.005  2.307
# 23    5894  pubchem.compound      10413  4-Hydroxybutanoic acid  0.005  2.303
# 24    4197  pubchem.compound     174174                Atropine  0.006  2.234
# 25    4973  pubchem.compound    5284603               Oxycodone  0.006  2.201
# 26     645  pubchem.compound        444               Bupropion  0.006  2.253
# 27    3914  pubchem.compound    1548968          (S)-Fluoxetine  0.006  2.207
# 28    4051  pubchem.compound       9651             Galantamine  0.006  2.251
# 29    4132  pubchem.compound       3519              Guanfacine  0.006  2.203
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
query, df = get_predictions_df('pubchem.compound:5095', 'phenotype')
print(json.dumps(query, indent=2))
df
#PMID: 29241812
# Out:
# {
#   "entity": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                         name    p    mlp  \
# 0        5      umls   C0002418                    Amblyopia  0.0  4.021
# 1     1210      umls   C0878544               Cardiomyopathy  0.0  3.531
# 2      225      umls   C0151315               Neck stiffness  0.0  3.542
# 3      227      umls   C1320474              Nuchal rigidity  0.0  4.443
# 4      278      umls   C0032326                 Pneumothorax  0.0  3.639
# 5      419      umls   C0020557        Hypertriglyceridaemia  0.0  3.401
# 6     1276      umls   C0151883         Vesiculobullous rash  0.0  3.334
# 7     1282      umls   C0836924               Thrombocytosis  0.0  3.484
# 8      346      umls   C0085606          Micturition urgency  0.0  3.425
# 9     1714      umls   C0004239               Atrial flutter  0.0  3.470
# 10     343      umls   C0040479           Torsade de pointes  0.0  3.604
# 11     409      umls   C0016658                     Fracture  0.0  3.520
# 12    1391      umls   C0019270                       Hernia  0.0  3.660
# 13     429      umls   C0030794                  Pelvic pain  0.0  3.795
# 14     436      umls   C0033117                     Priapism  0.0  4.140
# 15     455      umls   C0151734  Injection site inflammation  0.0  3.534
# 16     862      umls   C0392156                    Akathisia  0.0  4.127
# 17    2074      umls   C0085637            Oculogyric crisis  0.0  3.825
# 18     651      umls   C0005586             Bipolar disorder  0.0  3.386
# 19    1922      umls   C0007971                    Cheilitis  0.0  3.614
# 20    1413      umls   C0038363          Aphthous stomatitis  0.0  3.838
# 21    1696      umls   C2364111                      Ageusia  0.0  3.472
# 22     711      umls   C0020039                    Hostility  0.0  3.750
# 23     764      umls   C0038661                      Suicide  0.0  3.363
# 24     903      umls   C0574067              Cough increased  0.0  3.538
# 25    1836      umls   C0013415           Dysthymic disorder  0.0  3.327
# 26    1950      umls   C0151596        Tongue discolouration  0.0  3.523
# 27    1647      umls   C0037287                  Skin nodule  0.0  3.664
# 28    1763      umls   C0015402              Eye haemorrhage  0.0  3.552
# 29    2294      umls   C0015469             Facial paralysis  0.0  4.013
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
r = predictor.find_new_relation(
    source_id='2071', #Amantadine
    target_id='2248', #Parkinson's disease
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "2071",
#     "namespace": "pubchem.compound",
#     "identifier": "2130",
#     "name": "Amantadine"
#   },
#   "target": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease"
#   },
#   "p": 0.014,
#   "mlp": 1.852
# }

# %%
r = predictor.find_new_relation(
    source_id='5346', #Ropinirole
    target_id='1348', #Restless legs syndrome
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole"
#   },
#   "target": {
#     "node_id": "1348",
#     "namespace": "umls",
#     "identifier": "C0035258",
#     "name": "Restless legs syndrome"
#   },
#   "p": 0.002,
#   "mlp": 2.666
# }

# %%
r = predictor.find_new_relation(
    source_id='3627', #Disulfiram
    target_id='2318', #Malignant melanoma
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "3627",
#     "namespace": "pubchem.compound",
#     "identifier": "3117",
#     "name": "Disulfiram"
#   },
#   "target": {
#     "node_id": "2318",
#     "namespace": "umls",
#     "identifier": "C0025202",
#     "name": "Malignant melanoma"
#   },
#   "p": 0.886,
#   "mlp": 0.052
# }

# %%
r = predictor.find_new_relation(
    source_id='17528', #Brigatinib
    target_id='5148', #Colorectal cancer
)
print(json.dumps(r, indent=2))
#PMID: 31410188
# Out:
# {
#   "source": {
#     "node_id": "17528",
#     "namespace": "uniprot",
#     "identifier": "Q99640",
#     "name": "PMYT1_HUMAN"
#   },
#   "target": {
#     "node_id": "5148",
#     "namespace": "umls",
#     "identifier": "C1527249",
#     "name": "Colorectal cancer"
#   },
#   "p": 0.998,
#   "mlp": 0.001
# }

# %%
r = predictor.find_new_relation(
    source_id='6995', #dasatinib
    target_id='1179', #Diffuse large B-cell lymphoma
)
print(json.dumps(r, indent=2))
#PMID: 31383760
# Out:
# {
#   "source": {
#     "node_id": "6995",
#     "namespace": "pubchem.compound",
#     "identifier": "3062316",
#     "name": "Dasatinib"
#   },
#   "target": {
#     "node_id": "1179",
#     "namespace": "umls",
#     "identifier": "C0079744",
#     "name": "Diffuse large B-cell lymphoma"
#   },
#   "p": 0.536,
#   "mlp": 0.271
# }

# %%
r = predictor.find_new_relation(
    source_id='5265', #ribavirin
    target_id='947', #Candida infection
)
print(json.dumps(r, indent=2))
#PMID: 31307986
# Out:
# {
#   "source": {
#     "node_id": "5265",
#     "namespace": "pubchem.compound",
#     "identifier": "37542",
#     "name": "Ribavirin"
#   },
#   "target": {
#     "node_id": "947",
#     "namespace": "umls",
#     "identifier": "C0006840",
#     "name": "Candida infection"
#   },
#   "p": 0.025,
#   "mlp": 1.601
# }
