# %% [markdown]
# # Using the Prediction Model
#
# ## Environment

# %%
import getpass
import json
import os
import sys
import time

import pandas as pd
from tqdm import tqdm_notebook as tqdm

from seffnet.constants import (
    DEFAULT_EMBEDDINGS_PATH, DEFAULT_GRAPH_PATH,
    DEFAULT_MAPPING_PATH, DEFAULT_PREDICTIVE_MODEL_PATH,
    RESOURCES
)
from seffnet.literature import query_europe_pmc

# %%
print(sys.version)
# Out:
# 3.7.4 (default, Aug 13 2019, 11:17:01)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-36)]

# %%
print(time.asctime())
# Out:
# Tue Nov  5 10:30:02 2019

# %%
print(getpass.getuser())
# Out:
# raldisi

# %% [markdown]
# # Loading the Data

# %%
from seffnet.default_predictor import predictor

# %%
print(f"""Loaded default predictor using paths:

embeddings: {DEFAULT_EMBEDDINGS_PATH}
graph:      {DEFAULT_GRAPH_PATH}
model:      {DEFAULT_PREDICTIVE_MODEL_PATH}
mapping:    {DEFAULT_MAPPING_PATH}
""")
# Out:
# Loaded default predictor using paths:
#
# embeddings: /home/raldisi/seffnet/resources/embeddings/0411_weighted_node2vec_emb.embeddings
# graph:      /home/raldisi/seffnet/resources/basic_graphs/fullgraph_with_chemsim.edgelist
# model:      /home/raldisi/seffnet/resources/predictive_models/0411_weighted_node2vec_predictive_model.pkl
# mapping:    /home/raldisi/seffnet/resources/mapping/fullgraph_nodes_mapping.tsv

# %% [markdown]
# # Examples of different kinds of predictions with literature evidence

# %% [markdown]
# ## side effect - target association

# %%
r = predictor.find_new_relation(
    source_name='EGFR_HUMAN',
    target_name='Papulopustular rash',
)
print(json.dumps(r, indent=2))
#PMID: 18165622
# Out:
# {
#   "source": {
#     "node_id": "9587",
#     "namespace": "uniprot",
#     "identifier": "P00533",
#     "name": "EGFR_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "6791",
#     "namespace": "umls",
#     "identifier": "C2609319",
#     "name": "Papulopustular rash",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.841
# }

# %%
r = predictor.find_new_relation(
    source_id='9451', # Histamine receptor H1
    target_id='331', # Drowsiness
)
print(json.dumps(r, indent=2))
#PMID: 26626077
# Out:
# {
#   "source": {
#     "node_id": "9451",
#     "namespace": "uniprot",
#     "identifier": "P35367",
#     "name": "HRH1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "331",
#     "namespace": "umls",
#     "identifier": "C0013144",
#     "name": "Drowsiness",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.009
# }

# %%
r = predictor.find_new_relation(
    source_id='9325', # SC6A2
    target_id='56', # Tachycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "9325",
#     "namespace": "uniprot",
#     "identifier": "P23975",
#     "name": "SC6A2_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "56",
#     "namespace": "umls",
#     "identifier": "C0039231",
#     "name": "Tachycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.14
# }

# %%
r = predictor.find_new_relation(
    source_id='8670', # ACES_HUMAN
    target_id='309', # Bradycardia
)
print(json.dumps(r, indent=2))
#PMID: 30952858
# Out:
# {
#   "source": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "309",
#     "namespace": "umls",
#     "identifier": "C0428977",
#     "name": "Bradycardia",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.445
# }

# %% [markdown]
# ## drug- side effect association

# %%
r = predictor.find_new_relation(
    source_id='3534',  # diazepam
    target_id='670',  # Libido decreased
)
print(json.dumps(r, indent=2))
#PMID: 29888057
# Out:
# {
#   "source": {
#     "node_id": "3534",
#     "namespace": "pubchem.compound",
#     "identifier": "3016",
#     "name": "Diazepam",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "670",
#     "namespace": "umls",
#     "identifier": "C0011124",
#     "name": "Libido decreased",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.038
# }

# %%
r = predictor.find_new_relation(
    source_id='1148',  # Cytarabine 
    target_id='1149',  # Anaemia megaloblastic
)
print(json.dumps(r, indent=2))
# PMID: 23157436
# Out:
# {
#   "source": {
#     "node_id": "1148",
#     "namespace": "pubchem.compound",
#     "identifier": "6175",
#     "name": "Cytidine",
#     "entity_type": "experimental drug"
#   },
#   "target": {
#     "node_id": "1149",
#     "namespace": "umls",
#     "identifier": "C0002888",
#     "name": "Anaemia megaloblastic",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.309
# }

# %% [markdown]
# ## drug-target association

# %%
r = predictor.find_new_relation(
    source_id='14672',  # Sertindole 
    target_id='9350',   # CHRM1 receptor
)
print(json.dumps(r, indent=2))
# PMID: 29942259
# Out:
# {
#   "source": {
#     "node_id": "14672",
#     "namespace": "pubchem.compound",
#     "identifier": "60149",
#     "name": "Sertindole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "9350",
#     "namespace": "uniprot",
#     "identifier": "P11229",
#     "name": "ACM1_HUMAN",
#     "entity_type": "target"
#   },
#   "lor": 0.025
# }

# %% [markdown]
# # Example of predicting relations using node2vec model and embeddings

# %%
def get_predictions_df(curie, results_type=None):
    results = predictor.find_new_relations(
        node_curie=curie,
        results_type=results_type,
        k=30,
    )
    results_df = pd.DataFrame(results['predictions'])
    results_df = results_df[['node_id', 'namespace', 'identifier', 'name', 'lor', 'novel']]
    return results['query'], results_df

# %%
query, df = get_predictions_df('pubchem.compound:2159', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2173",
#     "namespace": "pubchem.compound",
#     "identifier": "2159",
#     "name": "Amisulpride",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                         name    lor  novel
# 0     1062      umls   C0497327                     Dementia  0.000   True
# 1     6249      umls   C0036337     Schizoaffective disorder  0.000   True
# 2      821      umls   C0233632            Thinking abnormal  0.001   True
# 3     1074      umls   C0575081             Gait disturbance  0.001   True
# 4      797      umls   C0338831                        Mania  0.001   True
# 5       28      umls   C0015397                 Eye disorder  0.002   True
# 6       41      umls   C0023218  Cramps of lower extremities  0.002   True
# 7      181      umls   C0036974                        Shock  0.002   True
# 8      816      umls   C0232461           Increased appetite  0.002   True
# 9      568      umls   C0018939               Blood disorder  0.002   True
# 10     540      umls   C0042075       Urinary tract disorder  0.002   True
# 11      44      umls   C0026826                   Hypertonia  0.002   True
# 12    1396      umls   C0023066                 Laryngospasm  0.002   True
# 13     950      umls   C0007787   Transient ischaemic attack  0.002   True
# 14     403      umls   C0002884          Hypochromic anaemia  0.002   True
# 15     535      umls   C0031212         Personality disorder  0.002   True
# 16    1539      umls   C0006384          Bundle branch block  0.002   True
# 17     799      umls   C0151836            Paranoid reaction  0.002   True
# 18     602      umls   C0013362                   Dysarthria  0.002   True
# 19     652      umls   C0853193           Bipolar I disorder  0.002   True
# 20     651      umls   C0005586             Bipolar disorder  0.002   True
# 21     552      umls   C0085628                       Stupor  0.002   True
# 22    2248      umls   C0030567          Parkinson's disease  0.002   True
# 23     684      umls   C0014394                     Enuresis  0.002   True
# 24     332      umls   C0020578             Hyperventilation  0.003   True
# 25     371      umls   C0014549         Grand mal convulsion  0.003   True
# 26     503      umls   C3665386              Abnormal vision  0.003   True
# 27     903      umls   C0574067              Cough increased  0.003   True
# 28     734      umls   C0028084                    Nightmare  0.003   True
# 29       5      umls   C0002418                    Amblyopia  0.003   True

# %%
query, df = get_predictions_df('pubchem.compound:4585', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "4915",
#     "namespace": "pubchem.compound",
#     "identifier": "4585",
#     "name": "Olanzapine",
#     "entity_type": "approved drug"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                       name  \
# 0      287      umls   C0042401                               Vasodilation
# 1      735      umls   C0028734                                   Nocturia
# 2      834      umls   C0235198                       Cerebration impaired
# 3     1016      umls   C0151766               Liver function test abnormal
# 4      870      umls   C0424000                          Suicidal ideation
# 5     1391      umls   C0019270                                     Hernia
# 6     2460      umls   C0162316                    Iron deficiency anaemia
# 7      474      umls   C0427008                                  Stiffness
# 8      774      umls   C0043387                                    Yawning
# 9      371      umls   C0014549                       Grand mal convulsion
# 10     663      umls   C0009319                                    Colitis
# 11    1399      umls   C0151603                         Generalised oedema
# 12     734      umls   C0028084                                  Nightmare
# 13     305      umls   C0392171                    Influenza-like symptoms
# 14     105      umls   C0031256                                  Petechiae
# 15     950      umls   C0007787                 Transient ischaemic attack
# 16    1137      umls   C0151539                       Blood urea increased
# 17     894      umls   C0547030                         Visual disturbance
# 18     676      umls   C0011606                     Dermatitis exfoliative
# 19     995      umls   C0034150                                    Purpura
# 20     954      umls   C0008325                              Cholecystitis
# 21    1479      umls   C0917798                         Cerebral ischaemia
# 22    1390      umls   C0019209                               Hepatomegaly
# 23     437      umls   C0033575                         Prostatic disorder
# 24     750      umls   C0034880                                Hyperacusis
# 25    2445      umls   C0235901                   Lacrimation abnormal NOS
# 26     767      umls   C0039503                                 Tendonitis
# 27    6259      umls   C0233633                      Bradypsychic response
# 28    7542      umls   C0024517  Major depressive disorder, single episode
# 29     818      umls   C0233477                                  Dysphoria
#
#       lor  novel
# 0   0.000   True
# 1   0.000   True
# 2   0.000   True
# 3   0.000   True
# 4   0.000   True
# 5   0.000   True
# 6   0.001   True
# 7   0.001   True
# 8   0.001   True
# 9   0.001   True
# 10  0.001   True
# 11  0.001   True
# 12  0.001   True
# 13  0.001   True
# 14  0.001   True
# 15  0.001   True
# 16  0.001   True
# 17  0.001   True
# 18  0.001   True
# 19  0.001   True
# 20  0.001   True
# 21  0.001   True
# 22  0.001   True
# 23  0.001   True
# 24  0.001   True
# 25  0.001   True
# 26  0.001   True
# 27  0.001   True
# 28  0.001   True
# 29  0.001   True

# %%
query, df = get_predictions_df('uniprot:P08172', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "9429",
#     "namespace": "uniprot",
#     "identifier": "P08172",
#     "name": "ACM2_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                  name    lor  \
# 0      198      umls   C0006266                          Bronchospasm  0.009
# 1      705      umls   C1322281                     Rhinitis seasonal  0.014
# 2     1823      umls   C0559031  Functional gastrointestinal disorder  0.015
# 3      398      umls   C0423153                           Lacrimation  0.016
# 4      957      umls   C0009443                           Common cold  0.020
# 5     2043      umls   C2607914                     Rhinitis allergic  0.021
# 6       81      umls   C0002792                    Anaphylactic shock  0.024
# 7      674      umls   C0011334                         Dental caries  0.024
# 8      673      umls   C0011253                              Delusion  0.025
# 9      728      umls   C0026837                       Muscle rigidity  0.030
# 10    2180      umls   C0152198                Accommodation disorder  0.031
# 11     668      umls   C0232849                          Bladder pain  0.034
# 12     924      umls   C0878773                    Hypertonic bladder  0.034
# 13     394      umls   C0036104                            Salivation  0.034
# 14     289      umls   C0043352                             Dry mouth  0.036
# 15     427      umls   C0026961                             Mydriasis  0.036
# 16    1297      umls   C0018794                           Block heart  0.038
# 17    3568      umls   C0235238                           Cycloplegia  0.038
# 18     780      umls   C0086439                           Hypokinesia  0.039
# 19    1398      umls   C0030920                          Peptic ulcer  0.046
# 20     852      umls   C0242422                          Parkinsonism  0.046
# 21     218      umls   C0040822                                Tremor  0.048
# 22    2248      umls   C0030567                   Parkinson's disease  0.048
# 23    5127      umls   C0027404                            Narcolepsy  0.048
# 24     821      umls   C0233632                     Thinking abnormal  0.049
# 25     224      umls   C0080274                     Urinary retention  0.049
# 26     395      umls   C0037036               Salivary hypersecretion  0.050
# 27    1909      umls   C1704272          Benign prostatic hyperplasia  0.051
# 28     625      umls   C0018524                         Hallucination  0.053
# 29     331      umls   C0013144                            Drowsiness  0.053
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
query, df = get_predictions_df('uniprot:P08588', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8733",
#     "namespace": "uniprot",
#     "identifier": "P08588",
#     "name": "ADRB1_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                     name  \
# 0     1325      umls   C0857121                             Hypertensive
# 1     7641      umls   C0017612                      Open angle glaucoma
# 2       38      umls   C0020538                             Hypertension
# 3      444      umls   C0039240             Supraventricular tachycardia
# 4     7640      umls   C0339573              Primary open angle glaucoma
# 5      198      umls   C0006266                             Bronchospasm
# 6     7709      umls   C0340288                   Stable angina pectoris
# 7     7642      umls   C0857070              Chronic open angle glaucoma
# 8     1714      umls   C0004239                           Atrial flutter
# 9      103      umls   C0027769                              Nervousness
# 10     349      umls   C0085614      Atrioventricular block first degree
# 11    7508      umls   C0043202           Wolff-Parkinson-White syndrome
# 12    8163      umls   C0242407              Hyperkinetic heart syndrome
# 13    7507      umls   C0030590  Paroxysmal supraventricular tachycardia
# 14      56      umls   C0039231                              Tachycardia
# 15     503      umls   C3665386                          Abnormal vision
# 16    1102      umls   C0002962                          Angina pectoris
# 17      47      umls   C0030252                             Palpitations
# 18     218      umls   C0040822                                   Tremor
# 19    3692      umls   C0085580                   Essential hypertension
# 20      10      umls   C0003811                               Arrhythmia
# 21    2203      umls   C0428974              Arrhythmia supraventricular
# 22    7769      umls   C0428776                            Cardiac index
# 23    4348      umls   C0232201                             Sinus rhythm
# 24     132      umls   C0234215                               Discomfort
# 25     331      umls   C0013144                               Drowsiness
# 26     270      umls   C0020550                          Hyperthyroidism
# 27     353      umls   C0151517          Atrioventricular block complete
# 28    5509      umls   C0011881                     Diabetic nephropathy
# 29    3494      umls   C0028840                      Ocular hypertension
#
#       lor  novel
# 0   0.002   True
# 1   0.003   True
# 2   0.005   True
# 3   0.007   True
# 4   0.009   True
# 5   0.011   True
# 6   0.012   True
# 7   0.013   True
# 8   0.014   True
# 9   0.015   True
# 10  0.016   True
# 11  0.016   True
# 12  0.017   True
# 13  0.018   True
# 14  0.019   True
# 15  0.020   True
# 16  0.020   True
# 17  0.022   True
# 18  0.022   True
# 19  0.023   True
# 20  0.024   True
# 21  0.024   True
# 22  0.024   True
# 23  0.026   True
# 24  0.028   True
# 25  0.031   True
# 26  0.032   True
# 27  0.032   True
# 28  0.032   True
# 29  0.033   True

# %%
query, df = get_predictions_df('uniprot:P22303', 'phenotype')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "8670",
#     "namespace": "uniprot",
#     "identifier": "P22303",
#     "name": "ACES_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "phenotype"
# }
#    node_id namespace identifier                                       name  \
# 0     3284      umls   C0151500                   Anticholinergic syndrome
# 1      224      umls   C0080274                          Urinary retention
# 2     1306      umls   C0028738                                  Nystagmus
# 3     2178      umls   C0030446                            Ileus paralytic
# 4      649      umls   C0004134                                     Ataxia
# 5      542      umls   C0235309                              Upset stomach
# 6     7542      umls   C0024517  Major depressive disorder, single episode
# 7     1072      umls   C0554976                               Bradyphrenia
# 8       42      umls   C0037763                              Muscle spasms
# 9      672      umls   C0011168                                  Dysphagia
# 10     371      umls   C0014549                       Grand mal convulsion
# 11    3273      umls   C0003635                                    Apraxia
# 12     316      umls   C2830004                                 Somnolence
# 13     730      umls   C0027066                                  Myoclonus
# 14     540      umls   C0042075                     Urinary tract disorder
# 15    4934      umls   C0043515                 Zollinger-Ellison syndrome
# 16     830      umls   C0235086            Muscle contractions involuntary
# 17    1961      umls   C0700361                         Emotional distress
# 18     602      umls   C0013362                                 Dysarthria
# 19    2009      umls   C0038220                         Status epilepticus
# 20     780      umls   C0086439                                Hypokinesia
# 21     186      umls   C0232495                       Abdominal pain lower
# 22    1742      umls   C0234369                                  Trembling
# 23     250      umls   C0020458                              Hyperhidrosis
# 24     347      umls   C0042023                                Pollakiuria
# 25    7845      umls   C0238111                    Lennox-Gastaut syndrome
# 26     591      umls   C0017168           Gastrooesophageal reflux disease
# 27    6399      umls   C0152159                          Uterine hypotonus
# 28     966      umls   C0014544                                   Epilepsy
# 29     822      umls   C1306341                          Mental disability
#
#       lor  novel
# 0   0.005   True
# 1   0.013   True
# 2   0.014   True
# 3   0.016   True
# 4   0.017   True
# 5   0.018   True
# 6   0.022   True
# 7   0.023   True
# 8   0.024   True
# 9   0.024   True
# 10  0.026   True
# 11  0.033   True
# 12  0.038   True
# 13  0.039   True
# 14  0.042   True
# 15  0.042   True
# 16  0.043   True
# 17  0.045   True
# 18  0.047   True
# 19  0.049   True
# 20  0.050   True
# 21  0.050   True
# 22  0.053   True
# 23  0.055   True
# 24  0.055   True
# 25  0.055   True
# 26  0.056   True
# 27  0.057   True
# 28  0.058   True
# 29  0.060   True

# %%
query, df = get_predictions_df('uniprot:Q9UBN7', 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "12164",
#     "namespace": "uniprot",
#     "identifier": "Q9UBN7",
#     "name": "HDAC6_HUMAN",
#     "entity_type": "target"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier  \
# 0    17378  pubchem.compound   11671467
# 1     1616  pubchem.compound       1690
# 2    16237  pubchem.compound   10250490
# 3    14968  pubchem.compound    6914612
# 4    15758  pubchem.compound     854023
# 5    14559  pubchem.compound     456390
# 6    17357  pubchem.compound    9865515
# 7     1412  pubchem.compound      89594
# 8     6474  pubchem.compound      82146
# 9    14072  pubchem.compound     444732
# 10   15656  pubchem.compound   24752833
# 11    1914  pubchem.compound       1990
# 12   17066  pubchem.compound      10235
# 13    6368  pubchem.compound      64147
# 14   13990  pubchem.compound  131704272
# 15    4623  pubchem.compound     126941
# 16   13540  pubchem.compound     656948
# 17   10931  pubchem.compound     440210
# 18   17374  pubchem.compound      26248
# 19   12447  pubchem.compound     445555
# 20    7118  pubchem.compound    6442177
# 21   16775  pubchem.compound     146089
# 22    1148  pubchem.compound       6175
# 23   11132  pubchem.compound     448879
# 24    7102  pubchem.compound   73425383
# 25     589  pubchem.compound     221493
# 26   13061  pubchem.compound      97032
# 27   14248  pubchem.compound     439750
# 28     521  pubchem.compound        244
# 29    7294  pubchem.compound   11707110
#
#                                                  name    lor  novel
# 0                                        Fostamatinib  0.015   True
# 1                                            AC1L1C0O  0.017   True
# 2   5-CHLORO-N-(2-(4-(2-OXOPYRIDIN-1(2H)-YL)BENZAM...  0.030   True
# 3   (1R,2R,3R,4S,5R)-4-(BENZYLAMINO)-5-(METHYLTHIO...  0.034   True
# 4                                         Epibatidine  0.041   True
# 5                                        Halofuginone  0.041   True
# 6                                        Mocetinostat  0.044   True
# 7                                            Nicotine  0.046   True
# 8                                          Bexarotene  0.049   True
# 9   7-[4-(Dimethylamino)Phenyl]-N-Hydroxy-4,6-Dime...  0.055   True
# 10  N-((1R,2R)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO...  0.056   True
# 11                               Acetohydroxamic acid  0.060   True
# 12                                           Cytisine  0.061   True
# 13                                     Valganciclovir  0.063   True
# 14                                           CGP 4832  0.065   True
# 15                                       Methotrexate  0.066   True
# 16                     Phosphorylated Dihydropteroate  0.069   True
# 17                   Bis(Adenosine)-5'-Pentaphosphate  0.069   True
# 18                                          Diacerein  0.071   True
# 19                2,5-Anhydroglucitol-1,6-Biphosphate  0.074   True
# 20                                         Everolimus  0.076   True
# 21               1,1,1-TRIFLUORO-3-(OCTYLTHIO)ACETONE  0.081   True
# 22                                           Cytidine  0.090   True
# 23                                N-Carbamyl-D-Valine  0.097   True
# 24                                           Eribulin  0.102   True
# 25                                        Cholic Acid  0.107   True
# 26           3,5,3',5'-Tetrachloro-Biphenyl-4,4'-Diol  0.107   True
# 27                                 N-Formylmethionine  0.111   True
# 28                                     Benzyl alcohol  0.114   True
# 29                                         Trametinib  0.115   True

# %%
query, df = get_predictions_df("umls:C0030567", 'chemical')
print(json.dumps(query, indent=2))
df
# Out:
# {
#   "entity": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "k": 30,
#   "type": "chemical"
# }
#    node_id         namespace identifier                         name    lor  \
# 0     4517  pubchem.compound       6279  Medroxyprogesterone acetate  0.001
# 1     5192  pubchem.compound       5994                 Progesterone  0.001
# 2     3629  pubchem.compound       3121                Valproic Acid  0.001
# 3     4499  pubchem.compound       3964                     Loxapine  0.001
# 4     4970  pubchem.compound       4634                   Oxybutynin  0.001
# 5     5753  pubchem.compound      60773                 Valaciclovir  0.001
# 6     2044  pubchem.compound       2118                   Alprazolam  0.001
# 7     3691  pubchem.compound       3157                    Doxazosin  0.001
# 8     3697  pubchem.compound     667468                    Cidoxepin  0.001
# 9     5617  pubchem.compound     443879                  Tolterodine  0.001
# 10    2199  pubchem.compound       2170                    Amoxapine  0.001
# 11    2573  pubchem.compound     644073                Buprenorphine  0.001
# 12    4712  pubchem.compound    3085218                Esmirtazapine  0.002
# 13    5101  pubchem.compound       5910                  Pilocarpine  0.002
# 14    5907  pubchem.compound      12453                     633-59-0  0.002
# 15    3488  pubchem.compound       2995                  Desipramine  0.002
# 16    2173  pubchem.compound       2159                  Amisulpride  0.002
# 17    6105  pubchem.compound    5311128                    Goserelin  0.002
# 18    6474  pubchem.compound      82146                   Bexarotene  0.002
# 19    5610  pubchem.compound      36294                   Tobramycin  0.002
# 20    4506  pubchem.compound       4011                  Maprotiline  0.002
# 21    4886  pubchem.compound      13109               Levonorgestrel  0.002
# 22    2935  pubchem.compound       2726               Chlorpromazine  0.002
# 23    5974  pubchem.compound      23978                       Copper  0.002
# 24    1237  pubchem.compound    3001028              Estrone sulfate  0.003
# 25    6006  pubchem.compound      27993                     AC1L1EDV  0.003
# 26    3187  pubchem.compound    1548953                 Enclomiphene  0.003
# 27    6206  pubchem.compound      60198                   Exemestane  0.003
# 28    6008  pubchem.compound      28486               Lithium cation  0.003
# 29    6632  pubchem.compound     125017               Desvenlafaxine  0.003
#
#     novel
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True

# %%
results = []
for ind, row in df.iterrows():
    pmcid = []
    lit = query_europe_pmc(
        query_entity=row['name'],
        target_entities=[
            'umls:C0030567'
        ],
    )
    i = 0
    for x in lit:
        if i > 5:
            pmcid.append('... ect')
            lit.close()
            break
        pmcid.append(x['pmcid'])
        i+=1
    results.append((len(pmcid), pmcid))
df['co-occurance'] = results

# %%
df
# Out:
#    node_id         namespace identifier                         name    lor  \
# 0     4517  pubchem.compound       6279  Medroxyprogesterone acetate  0.001
# 1     5192  pubchem.compound       5994                 Progesterone  0.001
# 2     3629  pubchem.compound       3121                Valproic Acid  0.001
# 3     4499  pubchem.compound       3964                     Loxapine  0.001
# 4     4970  pubchem.compound       4634                   Oxybutynin  0.001
# 5     5753  pubchem.compound      60773                 Valaciclovir  0.001
# 6     2044  pubchem.compound       2118                   Alprazolam  0.001
# 7     3691  pubchem.compound       3157                    Doxazosin  0.001
# 8     3697  pubchem.compound     667468                    Cidoxepin  0.001
# 9     5617  pubchem.compound     443879                  Tolterodine  0.001
# 10    2199  pubchem.compound       2170                    Amoxapine  0.001
# 11    2573  pubchem.compound     644073                Buprenorphine  0.001
# 12    4712  pubchem.compound    3085218                Esmirtazapine  0.002
# 13    5101  pubchem.compound       5910                  Pilocarpine  0.002
# 14    5907  pubchem.compound      12453                     633-59-0  0.002
# 15    3488  pubchem.compound       2995                  Desipramine  0.002
# 16    2173  pubchem.compound       2159                  Amisulpride  0.002
# 17    6105  pubchem.compound    5311128                    Goserelin  0.002
# 18    6474  pubchem.compound      82146                   Bexarotene  0.002
# 19    5610  pubchem.compound      36294                   Tobramycin  0.002
# 20    4506  pubchem.compound       4011                  Maprotiline  0.002
# 21    4886  pubchem.compound      13109               Levonorgestrel  0.002
# 22    2935  pubchem.compound       2726               Chlorpromazine  0.002
# 23    5974  pubchem.compound      23978                       Copper  0.002
# 24    1237  pubchem.compound    3001028              Estrone sulfate  0.003
# 25    6006  pubchem.compound      27993                     AC1L1EDV  0.003
# 26    3187  pubchem.compound    1548953                 Enclomiphene  0.003
# 27    6206  pubchem.compound      60198                   Exemestane  0.003
# 28    6008  pubchem.compound      28486               Lithium cation  0.003
# 29    6632  pubchem.compound     125017               Desvenlafaxine  0.003
#
#     novel                                       co-occurance
# 0    True  (7, [PMC2935455, PMC6483317, PMC3873843, PMC34...
# 1    True  (7, [PMC2763283, PMC4396568, PMC3051156, PMC64...
# 2    True  (7, [PMC4146011, PMC4269551, PMC2926634, PMC42...
# 3    True  (7, [PMC4442591, PMC6483410, NA, PMC5811827, P...
# 4    True  (7, [PMC4857824, PMC6463833, PMC6493371, PMC38...
# 5    True                                            (0, [])
# 6    True  (7, [PMC6494576, PMC4070603, PMC2823283, PMC64...
# 7    True  (7, [PMC4286669, PMC3858902, PMC2810806, PMC53...
# 8    True                                            (0, [])
# 9    True  (7, [PMC6463833, PMC3866282, PMC6493371, PMC17...
# 10   True  (7, [PMC4355567, PMC5701274, PMC4442591, PMC57...
# 11   True  (7, [PMC2693002, PMC6513058, PMC5719065, PMC57...
# 12   True                                            (0, [])
# 13   True  (7, [PMC6757526, PMC5214904, PMC5407108, PMC53...
# 14   True                                            (0, [])
# 15   True  (7, [PMC2680932, PMC4355567, PMC4279221, PMC40...
# 16   True  (7, [PMC6623749, PMC4364461, PMC6187640, PMC31...
# 17   True  (7, [PMC5561408, PMC3181967, PMC6473290, PMC45...
# 18   True  (7, [PMC4549399, PMC5644280, PMC6605427, PMC44...
# 19   True  (7, [PMC5964511, PMC5743843, PMC5345890, PMC49...
# 20   True  (7, [PMC4355567, PMC2809336, PMC2822849, PMC57...
# 21   True  (7, [PMC2766478, PMC4856424, PMC4403087, PMC38...
# 22   True  (7, [PMC3271486, PMC4366389, PMC4118918, PMC64...
# 23   True  (7, [PMC3941957, PMC3690345, PMC5400511, PMC36...
# 24   True  (7, [PMC2835398, PMC6151497, PMC3866684, PMC48...
# 25   True                                            (0, [])
# 26   True                                            (0, [])
# 27   True  (7, [NA, PMC3866684, PMC6157328, PMC5886305, P...
# 28   True                                            (0, [])
# 29   True  (7, [PMC4169791, PMC3421081, PMC5719067, PMC57...

# %%
df.to_csv(os.path.join(RESOURCES, 'parkinsons-chemicals.tsv'), sep='\t')

# %%
query, df = get_predictions_df('pubchem.compound:5095', 'phenotype')
print(json.dumps(query, indent=2))
df
#PMID: 29241812
# Out:
# {
#   "entity": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "k": 10,
#   "type": "phenotype"
# }
#   node_id namespace identifier                                    name    lor  \
# 0     763      umls   C0038325                Stevens-Johnson syndrome  0.000
# 1    1484      umls   C0014518              Toxic epidermal necrolysis  0.000
# 2    1139      umls   C0853034  Blood creatine phosphokinase increased  0.000
# 3     291      umls   C0085605                         Hepatic failure  0.000
# 4     536      umls   C0037317                       Sleep disturbance  0.000
# 5    7667      umls   C0008677                      Bronchitis chronic  0.001
# 6     903      umls   C0574067                         Cough increased  0.001
# 7    1104      umls   C0024115                           Lung disorder  0.001
# 8     862      umls   C0392156                               Akathisia  0.001
# 9     273      umls   C0026858                    Musculoskeletal pain  0.001
#
#    novel
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True

# %%
r = predictor.find_new_relation(
    source_id='2071', #Amantadine
    target_id='2248', #Parkinson's disease
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "2071",
#     "namespace": "pubchem.compound",
#     "identifier": "2130",
#     "name": "Amantadine",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2248",
#     "namespace": "umls",
#     "identifier": "C0030567",
#     "name": "Parkinson's disease",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.005
# }

# %%
r = predictor.find_new_relation(
    source_id='5346', #Ropinirole
    target_id='1348', #Restless legs syndrome
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "5346",
#     "namespace": "pubchem.compound",
#     "identifier": "5095",
#     "name": "Ropinirole",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1348",
#     "namespace": "umls",
#     "identifier": "C0035258",
#     "name": "Restless legs syndrome",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.007
# }

# %%
r = predictor.find_new_relation(
    source_id='3627', #Disulfiram
    target_id='2318', #Malignant melanoma
)
print(json.dumps(r, indent=2))
#PMID: 21654146
# Out:
# {
#   "source": {
#     "node_id": "3627",
#     "namespace": "pubchem.compound",
#     "identifier": "3117",
#     "name": "Disulfiram",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "2318",
#     "namespace": "umls",
#     "identifier": "C0025202",
#     "name": "Malignant melanoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.511
# }

# %%
r = predictor.find_new_relation(
    source_id='17528', #Brigatinib
    target_id='5148', #Colorectal cancer
)
print(json.dumps(r, indent=2))
#PMID: 31410188
# Out:
# {
#   "source": {
#     "node_id": "17528",
#     "namespace": "uniprot",
#     "identifier": "Q99640",
#     "name": "PMYT1_HUMAN",
#     "entity_type": "target"
#   },
#   "target": {
#     "node_id": "5148",
#     "namespace": "umls",
#     "identifier": "C1527249",
#     "name": "Colorectal cancer",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.821
# }

# %%
r = predictor.find_new_relation(
    source_id='6995', #dasatinib
    target_id='1179', #Diffuse large B-cell lymphoma
)
print(json.dumps(r, indent=2))
#PMID: 31383760
# Out:
# {
#   "source": {
#     "node_id": "6995",
#     "namespace": "pubchem.compound",
#     "identifier": "3062316",
#     "name": "Dasatinib",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "1179",
#     "namespace": "umls",
#     "identifier": "C0079744",
#     "name": "Diffuse large B-cell lymphoma",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.836
# }

# %%
r = predictor.find_new_relation(
    source_id='5265', #ribavirin
    target_id='947', #Candida infection
)
print(json.dumps(r, indent=2))
#PMID: 31307986
# Out:
# {
#   "source": {
#     "node_id": "5265",
#     "namespace": "pubchem.compound",
#     "identifier": "37542",
#     "name": "Ribavirin",
#     "entity_type": "approved drug"
#   },
#   "target": {
#     "node_id": "947",
#     "namespace": "umls",
#     "identifier": "C0006840",
#     "name": "Candida infection",
#     "entity_type": "phenotype"
#   },
#   "lor": 0.129
# }
