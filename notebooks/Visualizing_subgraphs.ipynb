# %%
from seffnet.utils import create_subgraph
from seffnet.constants import DEFAULT_WEIGHTED_FULLGRAPH_PICKLE
from pybel_jupyter import to_jupyter
import pybel
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1108 13:32:51.113599 139946187401024 __init__.py:690]
#
#   TensorFlow's `tf-nightly` package will soon be updated to TensorFlow 2.0.
#
#   Please upgrade your code to TensorFlow 2.0:
#     * https://www.tensorflow.org/beta/guide/migration_guide
#
#   Or install the latest stable TensorFlow 1.X release:
#     * `pip install -U "tensorflow==1.*"`
#
#   Otherwise your code may be broken by the change.

# %%
parkinson_val = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='3121',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
)

# %%
to_jupyter(parkinson_val)

# %%
parkinson_medro = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='6279',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
)

# %%
to_jupyter(parkinson_medro)

# %%
parkinson_pro = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='5994',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
    common_targets=True,
)

# %%
to_jupyter(parkinson_pro)

# %%
parkinson_lox = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='3964',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
    common_targets=True
)

# %%
to_jupyter(parkinson_lox)

# %%
parkinson_oxy = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='4634',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
)

# %%
to_jupyter(parkinson_oxy)

# %%
parkinson_vala = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='60773',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
    common_targets=True,
)
#Get longer paths

# %%
to_jupyter(parkinson_vala)

# %%
parkinson_cido = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='667468',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
)

# %%
to_jupyter(parkinson_cido)

# %%
parkinson_enc = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='1548953',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
    common_targets=True
)

# %%
to_jupyter(parkinson_enc)

# %%
parkinson_levo = create_subgraph(
    fullgraph_path=DEFAULT_WEIGHTED_FULLGRAPH_PICKLE,
    source_identifier='13109',
    source_type='chemical',
    target_name="Parkinson's disease",
    target_identifier='C0030567',
    target_type='phenotype',
    weighted=True,
    common_targets=True
    
)

# %%
to_jupyter(parkinson_levo)
